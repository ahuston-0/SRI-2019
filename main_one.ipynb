# %%
# Import Statements
import cv2 as cv
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from matplotlib import pyplot as plt
import time
import sys
import multiprocessing
import os
import rospy
from sensor_msgs.msg import Image
from stereo_msgs.msg import DisparityImage
from sensor_msgs.msg import PointCloud2
from nav_msgs.msg import OccupancyGrid as Map
import message_filters
import cv_bridge
import tf
import math
from std_msgs.msg import String

# %%
# Initialization Stuff

rospy.init_node('liveproc')

listener = tf.TransformListener()
pub = rospy.Publisher('updated_map', Map, queue_size=10)

occ_map = None
up_occ_map = None
map_resolution = 0.5
origin = None
robot_x = 0
robot_y = 0
map_width = 0

map_height = 0
camera_range = 85/map_resolution
overlay = False
display_robot_yaw = True
display_rect = True
display_map = True
display_info = False
tri_width = 5
dist_error = 0.15

np.set_printoptions(threshold=sys.maxsize)

# %%
def createLineIterator(P1, P2, img):
# """
# Produces and array that consists of the coordinates and intensities of
# each pixel in a line between two points

# Parameters:
#     -P1: a numpy array that consists of the coordinate of the first point (x,y)
#     -P2: a numpy array that consists of the coordinate of the second point (x,y)
#     -img: the image being processed

# Returns:
#     -it: a numpy array that consists of the coordinates and intensities of each
#     pixel in the radii (shape: [numPixels, 3], row = [x,y,intensity])     
# """
   #define local variables for readability
    #print img.shape
    image_height = img.shape[0]
    image_width = img.shape[1]
    P1X = P1[0]
    P1Y = P1[1]
    P2X = P2[0]
    P2Y = P2[1]
    
   #difference and absolute difference between points
   #used to calculate slope and relative location between points
    dX = P2X - P1X
    dY = P2Y - P1Y
    dXa = np.abs(dX)
    dYa = np.abs(dY)

    #predefine numpy array for output based on distance between points
    itbuffer = np.empty(shape=(np.maximum(dYa,dXa),3), dtype=np.int32)
    itbuffer.fill(np.nan)

   #Obtain coordinates along the line using a form of Bresenham's algorithm
    negY = P1Y > P2Y
    negX = P1X > P2X
    if P1X == P2X: #vertical line segment
        itbuffer[:,0] = P1X
        if negY:
            itbuffer[:,1] = np.arange(P1Y - 1,P1Y - dYa - 1,-1)
        else:
            itbuffer[:,1] = np.arange(P1Y+1,P1Y+dYa+1)              
    elif P1Y == P2Y: #horizontal line segment
        itbuffer[:,1] = P1Y
        if negX:
            itbuffer[:,0] = np.arange(P1X-1,P1X-dXa-1,-1)
        else:
            itbuffer[:,0] = np.arange(P1X+1,P1X+dXa+1)
    else: #diagonal line segment
        steepSlope = dYa > dXa
        if steepSlope:
            slope = dX.astype(np.float32)/dY.astype(np.float32)
            if negY:
                itbuffer[:,1] = np.arange(P1Y-1,P1Y-dYa-1,-1)
            else:
                itbuffer[:,1] = np.arange(P1Y+1,P1Y+dYa+1)
            itbuffer[:,0] = (slope*(itbuffer[:,1]-P1Y)).astype(np.int) + P1X
        else:
            slope = dY.astype(np.float32)/dX.astype(np.float32)
            if negX:
                itbuffer[:,0] = np.arange(P1X-1,P1X-dXa-1,-1)
            else:
                itbuffer[:,0] = np.arange(P1X+1,P1X+dXa+1)
            itbuffer[:,1] = (slope*(itbuffer[:,0]-P1X)).astype(np.int) + P1Y

   #Remove points outside of image
    colX = itbuffer[:,0]
    colY = itbuffer[:,1]
    itbuffer = itbuffer[(colX >= 0) & (colY >=0) & (colX<image_width) & (colY<image_height)]

   #Get intensities from img ndarray
    itbuffer[:,2] = img[itbuffer[:,1].astype(np.uint),itbuffer[:,0].astype(np.uint)]
    return itbuffer

# %%
def disp_rect(rect):
    cv.namedWindow("stereo/left/image_rect_color",cv.WINDOW_NORMAL)
    cv.imshow("stereo/left/image_rect_color", rect)
    cv.waitKey(1)

# %%
def disp_map(map_img):
    cv.namedWindow("map_inverted",cv.WINDOW_NORMAL)
    cv.imshow("map_inverted", map_img)
    cv.waitKey(1)

# %%
def transform(img):
    
    global bearings
    global areas
    global tags    
    
    bridge = cv_bridge.CvBridge()
    
    areas = []
    bearings = []
    tags = []
    
    width = img.height
    height = img.width
    
    img = bridge.imgmsg_to_cv2(img, desired_encoding="passthrough")
    
    img = cv.cvtColor(img, cv.COLOR_RGB2BGR)  
    
    
    image = pp(img,width,height)
    
    img2= dbscan(image, img)
    
    return img2
def pp(image, width, height):
    
    image = np.array(image[0:width][0:int(height*0.65)])
    image = cv.cvtColor(image, cv.COLOR_BGR2HSV)
    image[np.logical_not(np.logical_and(image[:,:,1] > 5,np.logical_or(np.logical_and(image[:,:,0] > 70, image[:,:,0] < 90),np.logical_or(image[:,:,0] >= 170, image[:,:,0] < 10))))] = [0,0,0]
    image = cv.cvtColor(image,cv.COLOR_HSV2BGR)

    return(image)
def dbscan(image, original):
    start_time_db = time.time()

    img = image.copy()
    img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    ret,thresh1 = cv.threshold(img,10,255,cv.THRESH_BINARY)

    nonzero = np.nonzero(thresh1)

    yp = np.array(nonzero[0])
    xp = np.array(nonzero[1])


    X=np.column_stack((xp,yp))

    if (len(X) > 0):
        start_time = time.time()
        db = DBSCAN(eps=3, min_samples=10).fit(X)
        labels = db.labels_

        array = zip(xp,yp,labels)
        sort = sorted(list(array), key=lambda x: x[2])

        x = 0
        while (len(sort) > 0 and sort[x][2] == -1):
            del sort[x]

        if (len(sort) > 0):
            unique_labels = sorted(set(labels))
            if (unique_labels[0] == -1):
                unique_labels.remove(-1)
            points = sort
            points = np.delete(points,2,1)

            i = 0
            x = 0
            l = []
            while (x < len(unique_labels)):
                if (i < len(sort) and sort[i][2] == x):
                    l.append(points[i])
                    i+=1
                else:
                    x+=1
#                     time_color = time.time()
                    clr = color_hsv(np.array(l),image)
#                     print "color ", time.time()-time_color
#                     time_rect = time.time()
                    tb = rectangle(np.array(l),clr,image,original)
#                     print "rect ", time.time()-time_rect
#                     print ""
                    l = []
            original = tb
#     print time.time()-start_time_db
#     print "\n"
    return original
def color_hsv(mat, image):
    
    image = cv.cvtColor(image, cv.COLOR_BGR2HSV)
    sumhue = 0
    sumsat = 0
    sumval = 0
    mat_add = 0
    for x in range(len(mat)):
        if(image [mat[x][1]] [mat[x][0]] [2] > 5):
            mat_add = mat_add+1
            sumval += image [mat[x][1]] [mat[x][0]] [2]
            sumsat += image [mat[x][1]] [mat[x][0]] [1]
            sumhue += image [mat[x][1]] [mat[x][0]] [0]
    if mat_add > 0:
        sat = sumsat/mat_add
        val = sumval/mat_add
        hue = sumhue/mat_add
        #return (hue, sat, val)
        if (sat > 5 and val > 5 and (hue < 60 or hue >= 170)):
            return 'red'
        if (sat > 5 and val > 5 and (70 < hue < 90)):
            return 'green'
        else:
            return (hue, sat, val)

    return None

# %%
def rectangle(mat,color,image,original):
    
    global bearings
    global overlay
    global occ_map
    global tags
    global display_info
    global map_resolution
    global areas
    
    rect = cv.boundingRect(mat)
    min_rect = cv.minAreaRect(mat)

    height = rect[3]
    width = rect[2]
    x = rect[0]
    x = np.int0(x)
    y = rect[1] 
    y = np.int0(y)
    font = cv.FONT_HERSHEY_SIMPLEX
    tag = 0
    if overlay:
        if (width < height and 4*width > height and width*height > 45):
            if(color =='green'):
                tag = 2
                cv.putText(original,color+' buoy',(np.int0(x-width/2),np.int0(y-height/2.5)), font, 0.5,(0,128,0),2,cv.LINE_AA)
                tags.append(tag)
            elif(color =='red'):
                tag = 3
                cv.putText(original,color+' buoy',(np.int0(x-width/2),np.int0(y-height/2.5)), font, 0.5,(0,0,128),2,cv.LINE_AA)
                tags.append(tag)
            else:
                tag = 1
                cv.putText(original,'buoy',(np.int0(x-width/2),np.int0(y-height/2.5)), font, 0.5,(255,255,255),2,cv.LINE_AA)
                tags.append(tag)
            cv.rectangle(original,(x,y),(x+width,y+height),(255,0,255),2)
            bearing = (min_rect[0][0]-640.0)/1280.0*80.0
            bearings.append(bearing)
            area = min_rect[1][0]*min_rect[1][1]
            areas.append(area)
#             print("Area: " + str(area) + " and Tag: " + str(tag) +
#                   "\nEstimated Distance: " + str(2*map_resolution*456.7946397925*math.pow(area,-0.4705300238)))
            if display_info and occ_map.header.seq % 5 == 0:
                print bearings
                print tags
        if(tag == 0):
            image[y:y+height][x:x+width]=[0,0,0]
        return original
    else:
        if (width < height and 4*width > height and width*height > 45):
            if(color =='green'):
                tag = 2
                cv.putText(image,color+' buoy',(np.int0(x-width/2),np.int0(y-height/2.5)), font, 0.5,(255,255,255),2,cv.LINE_AA)
                tags.append(tag)
            elif(color =='red'):
                tag = 3
                cv.putText(image,color+' buoy',(np.int0(x-width/2),np.int0(y-height/2.5)), font, 0.5,(255,255,255),2,cv.LINE_AA)
                tags.append(tag)
            else:
                tag = 1
                cv.putText(image,'buoy',(np.int0(x-width/2),np.int0(y-height/2.5)), font, 0.5,(255,255,255),2,cv.LINE_AA)
                tags.append(tag)
            cv.rectangle(image,(x,y),(x+width,y+height),(255,0,255),2)
            bearing = (min_rect[0][0]-640.0)/1280.0*80.0
            bearings.append(bearing)
            area = min_rect[1][0]*min_rect[1][1]
            areas.append(area)
#             print("Area: " + str(area) + " and Tag: " + str(tag) +
#                   "\nEstimated Distance: " + str(2*map_resolution*456.7946397925*math.pow(area,-0.4705300238)))
            if display_info and occ_map.header.seq % 5 == 0:
                print bearings
                print tags
        return image

# %%
def edgeFunction(a,b,c):
    det = (c[1]-a[1]) * (b[0]-a[0]) - (c[0]-a[0]) * (b[1]-a[1])
    return det

# %%
def rasterizeTri(a,b,c,region):
################################################################
# Rasterize a triangle given three points, a region to search,
#  and a dictionary defining map colors. All points are in (x,y)
#  format
#
# Parameters:
# - a,b: 2 points defining the far vertices of the triangle
# - c: The point where the WAM-V is in occ_map
# - d: The point where the WAM-V is in region
# - region: a portion of the occ_map where the triangle may be
# - values: a dict with the point values defining red and green
#     buoys
#
# Returns:
# - new_region: a region color-coded to highlight the triangle
#     and any buoys in the rasterized region
################################################################
    #print(region)
    region[region < 0] = 0
    #print region
    mask = np.array(np.zeros_like(region.copy()))
    updated = cv.fillPoly(mask, [a,b,c], 255)
    print updated
    
    rast_list = []
    start_time = time.time()
    for i in range(int(min(a[0],b[0],c[0])),int(max(a[0],b[0],c[0]))):
        for j in range(int(min(a[1],b[1],c[1])),int(max(a[1],b[1],c[1]))):
            w0 = edgeFunction(b,c,(i,j))
            w1 = edgeFunction(c,a,(i,j))
            w2 = edgeFunction(a,b,(i,j))

            if w0 >= 0 and w1 >= 0 and w2 >= 0:
                rast_list.append([(i),(j),region[i][j]])
#                 if region[i][j] == values.get("green"):
#                     new_region[i][j] = 255
#                 elif region[i][j] == values.get("red"):
#                     new_region[i][j] = 180
#                 else:
#                     new_region[i][j] = 100
    print time.time()-start_time
    return rast_list

# %%
def draw_background_objects(map_img,map_np):
    
    global origin
    global robot_x
    global robot_y
    
    o_x = (-origin.x)/map_resolution
    o_y = (-origin.y)/map_resolution
# Color Assignment Section
    map_img[map_np == -1] = [255,255,255]    #Change to [255,255,255] for color to [255] for grayscale
    map_img[map_np == 0] = [255,255,255]     #Change to [255,255,255] for color to [255] for grayscale
    map_img[map_np == 100] = [0,0,0]#Change to [0,0,0] for color to [0] for grayscale
    origin_color = [0,0,255]#Change to [0,0,255] for color to [0] for grayscale
    robot_color = [0,0,255]#Change to [0,0,255] for color to [0] for grayscale
# Origin (Drawn as a cross)

    map_img[int(o_y)+0][int(o_x)+0] = origin_color
    map_img[int(o_y)+0][int(o_x)+1] = origin_color
    map_img[int(o_y)+0][int(o_x)+2] = origin_color
    map_img[int(o_y)+1][int(o_x)+0] = origin_color
    map_img[int(o_y)+2][int(o_x)+0] = origin_color
    if (-origin.x) != 0:
        map_img[int(o_y)+0][int(o_x)-1] = origin_color
        map_img[int(o_y)+0][int(o_x)-2] = origin_color
    if (-origin.y) != 0:
        map_img[int(o_y)-1][int(o_x)+0] = origin_color
        map_img[int(o_y)-2][int(o_x)+0] = origin_color
# Robot (Drawn as a square)
    map_img[int(robot_y)+0][int(robot_x)+0] = robot_color
    map_img[int(robot_y)+0][int(robot_x)+2] = robot_color
    map_img[int(robot_y)+1][int(robot_x)+2] = robot_color
    map_img[int(robot_y)-1][int(robot_x)+2] = robot_color
    map_img[int(robot_y)+0][int(robot_x)-2] = robot_color
    map_img[int(robot_y)+1][int(robot_x)-2] = robot_color
    map_img[int(robot_y)-1][int(robot_x)-2] = robot_color
    map_img[int(robot_y)+2][int(robot_x)+0] = robot_color
    map_img[int(robot_y)+2][int(robot_x)+1] = robot_color
    map_img[int(robot_y)+2][int(robot_x)-1] = robot_color
    map_img[int(robot_y)-2][int(robot_x)+0] = robot_color
    map_img[int(robot_y)-2][int(robot_x)+1] = robot_color
    map_img[int(robot_y)-2][int(robot_x)-1] = robot_color
    
    return map_img

# %%
def draw_ray(map_img,slices):
    
    global display_robot_yaw
    global bearings
    global tags
    global areas
    global robot_x
    global robot_y
    global map_resolution
    global areas
    
    slices_size = len(slices)
    
    if not(display_robot_yaw):
        for i in range(int(slices_size)):
            try:
                arr = slices[i]
                appr_dist_low = (1.0-2.5*dist_error)*map_resolution*2*456.7946397925*math.pow(areas[i],-0.4705300238)
#############################
#                 print (arr.size)
#                 if (arr[:,4] > appr_dist_low):
#                     if (ray[2] == -1 or ray[2] == 0):
#                         map_img[ray[1]][ray[0]] = [255,0,0]
#                     elif ray[2] == 100:
#                         if tags[i] == 2: #here
#                             map_img[ray[1]][ray[0]]=[0,255,0]#Change to [0,255,0] for color to [180 for grayscale]
# #                             print("Distance from buoy: " + str(map_resolution*math.sqrt(math.pow((ray[1]-robot_y),2)+math.pow((ray[0]-robot_x),2))) 
# #                                   + "Tag: green"
# #                                   + "Area: " + str(areas[i]) +
# #                                   "\nEstimated Distance: " + str(2*map_resolution*456.7946397925*math.pow(areas[i],-0.4705300238)))
# #                             print ("")
#                             found = True
#                         if tags[i] == 3: #and here
#                             map_img[ray[1]][ray[0]]=[0,0,255]#Change to [0,0,255] for color to [230] for grayscale
# #                             print("Distance from buoy: " + str(map_resolution*math.sqrt(math.pow((ray[1]-robot_y),2)+math.pow((ray[0]-robot_x),2))) 
# #                                   + " Tag: red"
# #                                   + "Area: " + str(areas[i]) +
# #                                   "\nEstimated Distance: " + str(2*map_resolution*456.7946397925*math.pow(areas[i],-0.4705300238)))
# #                             print ("")
#                             found = True
####################
                for ray in arr:
                    if ray[3] > appr_dist_low: 
                        if (ray[2] == -1 or ray[2] == 0):
                            if True: #display true if you want to see slice
                                map_img[ray[1]][ray[0]] = [255,0,0]#Change to [255,0,0] for color to [0] for grayscale
                        if ray[2] == 100:
                            if tags[i] == 2:
                                map_img[ray[1]][ray[0]]=[0,255,0]#Change to [0,255,0] for color to [180 for grayscale]
                            if tags[i] == 3: 
                                map_img[ray[1]][ray[0]]=[0,0,255]#Change to [0,0,255] for color to [230] for grayscale
            except Exception as ex:
                print ex
    else:
        for arr in slices[-1]:
            map_img[arr[1]][arr[0]] = [0,255,0]
    
    return map_img

# %%
def get_mapnbot_info(trans,robot_yaw):

    global map_resolution
    global robot_x
    global robot_y
    global map_width
    global map_height
    global origin
    global occ_map
    global map_np
    
    map_array = occ_map.data

    map_width = occ_map.info.width
    map_height = occ_map.info.height
    map_np = np.reshape(np.array(map_array),(map_height,map_width))
    robot_x = (trans[0]-origin.x)/map_resolution
    robot_y = (trans[1]-origin.y)/map_resolution
    robot_yaw = (90 - robot_yaw)
    while robot_yaw > 360:
        robot_yaw = robot_yaw - 360
    while robot_yaw < 0:
        robot_yaw = robot_yaw + 360
    
    return map_np, robot_yaw

# %%
def insidetriangle((x1,x2,x3),(y1,y2,y3),map_np):

    global robot_x
    global robot_y
    
    xs=np.array((x1,x2,x3),dtype=float)
    ys=np.array((y1,y2,y3),dtype=float)

    # The possible range of coordinates that can be returned
    x_range=np.arange(np.min(xs),np.max(xs)+1)
    y_range=np.arange(np.min(ys),np.max(ys)+1)

    # Set the grid of coordinates on which the triangle lies. The centre of the
    # triangle serves as a criterion for what is inside or outside the triangle.
    X,Y=np.meshgrid( x_range,y_range )
    xc=np.mean(xs)
    yc=np.mean(ys)

    # From the array 'triangle', points that lie outside the triangle will be
    # set to 'False'.
    triangle = np.ones(X.shape,dtype=bool)
    for i in range(3):
        ii=(i+1)%3
        if xs[i]==xs[ii]:
            include = X *(xc-xs[i])/abs(xc-xs[i]) > xs[i] *(xc-xs[i])/abs(xc-xs[i])
        else:
            poly=np.poly1d([(ys[ii]-ys[i])/(xs[ii]-xs[i]),ys[i]-xs[i]*(ys[ii]-ys[i])/(xs[ii]-xs[i])])
            include = Y *(yc-poly(xc))/abs(yc-poly(xc)) > poly(X) *(yc-poly(xc))/abs(yc-poly(xc))
        triangle*=include

    # Output: 2 arrays with the x- and y- coordinates of the points inside the
    # triangle.
    

    x_points = X[triangle]
    y_points = Y[triangle]

    points = np.column_stack((x_points.astype(int), y_points.astype(int)))

    itbuffer = np.empty(shape=((points.size/2),4), dtype=np.int32)
    itbuffer.fill(np.nan)

    itbuffer[:,0] = x_points
    itbuffer[:,1] = y_points
    itbuffer[:,2] = map_np[points[:,1],points[:,0]]

# Get distance values    

    deltax = itbuffer[:,0]-robot_x
    deltay = itbuffer[:,1]-robot_y
    
    deltax = map_resolution*deltax
    deltay = map_resolution*deltay
    
    
    deltax = np.square(deltax)
    deltay = np.square(deltay)

    
    dist_sq = deltax+deltay
    
    dist_sq = np.sqrt(dist_sq)
#     dist_sq = map_resolution*dist_sq
    
    
    itbuffer[:,3] = dist_sq
#     print robot_x,robot_y
#     print np.column_stack((deltax.astype(int),deltay.astype(int)))
    return itbuffer

# %%
def get_points(buoy_yaw, index):
    
    global robot_x
    global robot_y
    global camera_range
    global tri_width
    global areas
    global dist_error
    
    appr_dist_up = (1.0+dist_error)*2*456.7946397925*math.pow(areas[index],-0.4705300238)
    point_deltax = camera_range * math.sin(math.radians(buoy_yaw)) # appr_dist_up
    point_deltay = camera_range * math.cos(math.radians(buoy_yaw)) #appr_dist_up
    per_slope = -1.0/(point_deltay/point_deltax)
    point1 = np.array([round(robot_x), round(robot_y)], dtype=int)
    point2 = np.array([round(robot_x+point_deltax), round(robot_y+point_deltay)], dtype=int)

    
    
    point3_x = (robot_x+point_deltax) + math.sqrt(math.pow(tri_width,2)/(math.pow(per_slope,2)+1))
    point4_x = (robot_x+point_deltax) - math.sqrt(math.pow(tri_width,2)/(math.pow(per_slope,2)+1))

    point3_y = robot_y+point_deltay + per_slope*(point3_x-(robot_x+point_deltax))
    point4_y = robot_y+point_deltay + per_slope*(point4_x-(robot_x+point_deltax))

    point3 = np.array([round(point3_x),round(point3_y)], dtype=int)
    point4 = np.array([round(point4_x),round(point4_y)], dtype=int)
    
    
    return point1,point2,point3,point4

# %%
def map_filter(trans, robot_yaw):
    
    global origin
    global robot_x
    global robot_y
    global camera_range
    global occ_map
    global bearings
    global display_robot_yaw
    global tags
    
    map_np, robot_yaw = get_mapnbot_info(trans,robot_yaw) 
    

    
    slices = []
    i = 0
    while (i < len(bearings)):
        
        
        buoy_yaw = robot_yaw + bearings[i]
        if ((buoy_yaw) < 0):
            buoy_yaw = buoy_yaw + 360
#         print bearings
##############################################################################
# This is for visualization purposes.
# Set to false if you don't want to display the robot_yaw
# Delete it if it's irritating to look at
        if display_robot_yaw and occ_map.header.seq % 5 == 0:
            bearings.append(0.0)
            print "Robot_yaw: ", robot_yaw
            print "Buoy yaw: ", buoy_yaw
            print len(slices)
##############################################################################
        
        pt1, pt2, pt3, pt4 = get_points(buoy_yaw, i)    
        
        sliced = createLineIterator(pt1.astype(int),pt2.astype(int),map_np)

#         sliced = insidetriangle((pt3[0],pt1[0],pt4[0]),(pt3[1],pt1[1],pt4[1]),map_np)
        slices.append(np.array(sliced).astype(int))

        i+=1
    
    return slices

# %%
def get_map(slices):
    
    global camera_range
    global origin
    global robot_x
    global robot_y
    global map_width
    global map_height
    global occ_map
    
    map_np = np.reshape(np.array(occ_map.data),(map_height,map_width))

    #Set to 1 when publishing, to 3 for visualization
    
    map_img_z = np.zeros((map_height, map_width, 3))
    
    map_img_b = draw_background_objects(map_img_z,map_np)
    
    if False:
        map_img_b = np.swapaxes(map_img_b, 0, 1)
        cv.namedWindow("map_inverted",cv.WINDOW_NORMAL)
        cv.imshow("map_inverted", map_img_b)
        cv.waitKey(1)
    
    map_img_r = draw_ray(map_img_b,slices)
    
    map_img = np.swapaxes(map_img_r, 0, 1)
    
    return map_img

# %%
def callback(rect):
#     start_time = time.time()
    global occ_map
    global origin
    global bearings
    global listener 
    global display_rect
    global display_map
    global tags
    global up_occ_map
    global pub
    global map_height
    global map_width
    
    origin = occ_map.info.origin.position
    rect = transform(rect)
    
    if not rospy.is_shutdown():       
        try:
            now = rospy.Time.now()
            listener.waitForTransform("/odom", "/front_left_camera_link", now, rospy.Duration(0.5))
            (trans,rot) = listener.lookupTransform("/odom", "/front_left_camera_link", now)
            euler = tf.transformations.euler_from_quaternion(rot)
            pixel_lines = map_filter(trans, math.degrees(euler[2]))
            map_image = get_map(pixel_lines)
#             print (time.time()-start_time)
            if True: #set to false if you don't want to publush the updated occupancy map
#                 up_occ_map_data = np.reshape(np.array(map_image),((map_width*map_height),1))
                pub.publish(up_occ_map)
                
            if display_rect == True:
                disp_rect(rect)
            if display_map == True:
                disp_map(map_image)
        except tf.LookupException as l:
            print l
        except tf.ConnectivityException as c:
            print c
        except tf.ExtrapolationException as e:
            print e
        except Exception as ex:
            print ex

# %%
def map_callback(p_map):
    
    global occ_map
    global up_occ_map
    
    occ_map = p_map    
    up_occ_map = p_map

# %%
if __name__ == '__main__':
    proj_map = rospy.Subscriber("projected_map", Map, map_callback)
    rect = rospy.Subscriber("stereo/left/image_rect_color", Image, callback)
    rospy.spin()
# Out:
# Robot_yaw:  266.786756578
# Buoy yaw:  262.255506578
# 0
# Robot_yaw:  266.786756578
# Buoy yaw:  248.661756578
# 1
# Robot_yaw:  266.786756578
# Buoy yaw:  297.333387438
# 2
# Robot_yaw:  266.786756578
# Buoy yaw:  246.520994249
# 3
# Robot_yaw:  266.786756578
# Buoy yaw:  266.786756578
# 4
# list index out of range
# Robot_yaw:  266.759917788
# Buoy yaw:  262.197417788
# 0
# Robot_yaw:  266.759917788
# Buoy yaw:  248.634917788
# 1
# Robot_yaw:  266.759917788
# Buoy yaw:  297.220244936
# 2
# Robot_yaw:  266.759917788
# Buoy yaw:  246.666167788
# 3
# Robot_yaw:  266.759917788
# Buoy yaw:  266.759917788
# 4
# list index out of range
# Robot_yaw:  266.704087101
# Buoy yaw:  262.141587101
# 0
# Robot_yaw:  266.704087101
# Buoy yaw:  248.519175373
# 1
# Robot_yaw:  266.704087101
# Buoy yaw:  297.416931949
# 2
# Robot_yaw:  266.704087101
# Buoy yaw:  246.547837101
# 3
# Robot_yaw:  266.704087101
# Buoy yaw:  266.704087101
# 4
# list index out of range
# Robot_yaw:  266.668891629
# Buoy yaw:  262.106391629
# 0
# Robot_yaw:  266.668891629
# Buoy yaw:  248.533548078
# 1
# Robot_yaw:  266.668891629
# Buoy yaw:  297.412887296
# 2
# Robot_yaw:  266.668891629
# Buoy yaw:  246.430652341
# 3
# Robot_yaw:  266.668891629
# Buoy yaw:  266.668891629
# 4
# list index out of range
# Robot_yaw:  266.72633646
# Buoy yaw:  262.19508646
# 0
# Robot_yaw:  266.72633646
# Buoy yaw:  248.60133646
# 1
# list index out of range
# Robot_yaw:  266.78182895
# Buoy yaw:  262.25057895
# 0
# Robot_yaw:  266.78182895
# Buoy yaw:  248.78182895
# 1
# Robot_yaw:  266.78182895
# Buoy yaw:  297.167944978
# 2
# Robot_yaw:  266.78182895
# Buoy yaw:  246.75057895
# 3
# Robot_yaw:  266.78182895
# Buoy yaw:  266.78182895
# 4
# list index out of range
# Robot_yaw:  266.762009963
# Buoy yaw:  262.230759963
# 0
# Robot_yaw:  266.762009963
# Buoy yaw:  248.730759963
# 1
# Robot_yaw:  266.762009963
# Buoy yaw:  297.153390273
# 2
# Robot_yaw:  266.762009963
# Buoy yaw:  246.730758056
# 3
# Robot_yaw:  266.762009963
# Buoy yaw:  266.762009963
# 4
# list index out of range
# Robot_yaw:  266.784018293
# Buoy yaw:  262.252768293
# 0
# Robot_yaw:  266.784018293
# Buoy yaw:  248.690268293
# 1
# Robot_yaw:  266.784018293
# Buoy yaw:  297.363859907
# 2
# Robot_yaw:  266.784018293
# Buoy yaw:  246.661648527
# 3
# Robot_yaw:  266.784018293
# Buoy yaw:  232.718570009
# 4
# Robot_yaw:  266.784018293
# Buoy yaw:  266.784018293
# 5
# list index out of range
# Robot_yaw:  266.673582415
# Buoy yaw:  248.489940981
# 1
# Robot_yaw:  266.673582415
# Buoy yaw:  297.629850725
# 2
# Robot_yaw:  266.673582415
# Buoy yaw:  246.454832415
# 3
# Robot_yaw:  266.673582415
# Buoy yaw:  266.673582415
# 4
# list index out of range
# Robot_yaw:  266.68443804
# Buoy yaw:  262.18443804
# 0
# Robot_yaw:  266.68443804
# Buoy yaw:  248.55943804
# 1
# Robot_yaw:  266.68443804
# Buoy yaw:  297.763760855
# 2
# Robot_yaw:  266.68443804
# Buoy yaw:  246.49693804
# 3
# Robot_yaw:  266.68443804
# Buoy yaw:  266.68443804
# 4
# list index out of range
# Robot_yaw:  266.768104514
# Buoy yaw:  262.268104514
# 0
# Robot_yaw:  266.768104514
# Buoy yaw:  248.736854514
# 1
# Robot_yaw:  266.768104514
# Buoy yaw:  297.268104514
# 2
# Robot_yaw:  266.768104514
# Buoy yaw:  246.364259681
# 3
# Robot_yaw:  266.768104514
# Buoy yaw:  266.768104514
# 4
# list index out of range
# Robot_yaw:  266.774164532
# Buoy yaw:  262.405413006
# 0
# Robot_yaw:  266.774164532
# Buoy yaw:  248.742914532
# 1
# Robot_yaw:  266.774164532
# Buoy yaw:  297.352381084
# 2
# Robot_yaw:  266.774164532
# Buoy yaw:  246.680414532
# 3
# Robot_yaw:  266.774164532
# Buoy yaw:  235.671223972
# 4
# Robot_yaw:  266.774164532
# Buoy yaw:  266.774164532
# 5
# list index out of range
# Robot_yaw:  266.731160229
# Buoy yaw:  262.199910229
# 0
# Robot_yaw:  266.731160229
# Buoy yaw:  248.574910229
# 1
# Robot_yaw:  266.731160229
# Buoy yaw:  297.796200817
# 2
# Robot_yaw:  266.731160229
# Buoy yaw:  246.546299999
# 3
# Robot_yaw:  266.731160229
# Buoy yaw:  237.449910229
# 4
# Robot_yaw:  266.731160229
# Buoy yaw:  266.731160229
# 5
# list index out of range
# Robot_yaw:  266.745748894
# Buoy yaw:  262.245748894
# 0
# Robot_yaw:  266.745748894
# Buoy yaw:  248.714498894
# 1
# Robot_yaw:  266.745748894
# Buoy yaw:  297.79949035
# 2
# Robot_yaw:  266.745748894
# Buoy yaw:  245.438269036
# 3
# Robot_yaw:  266.745748894
# Buoy yaw:  266.745748894
# 4
# list index out of range
# Robot_yaw:  266.748918077
# Buoy yaw:  262.248918077
# 0
# list index out of range
# Robot_yaw:  266.662071349
# Buoy yaw:  262.130821349
# 0
# Robot_yaw:  266.662071349
# Buoy yaw:  248.537071349
# 1
# Robot_yaw:  266.662071349
# Buoy yaw:  297.568321349
# 2
# Robot_yaw:  266.662071349
# Buoy yaw:  246.351028563
# 3
# Robot_yaw:  266.662071349
# Buoy yaw:  266.662071349
# 4
# list index out of range
# Robot_yaw:  266.656071413
# Buoy yaw:  262.156071413
# 0
# Robot_yaw:  266.656071413
# Buoy yaw:  248.531071413
# 1
# Robot_yaw:  266.656071413
# Buoy yaw:  297.592358339
# 2
# Robot_yaw:  266.656071413
# Buoy yaw:  246.379360903
# 3
# Robot_yaw:  266.656071413
# Buoy yaw:  266.656071413
# 4
# list index out of range
# Robot_yaw:  266.710395644
# Buoy yaw:  262.179145644
# 0
# Robot_yaw:  266.710395644
# Buoy yaw:  248.522895644
# 1
# Robot_yaw:  266.710395644
# Buoy yaw:  298.245529006
# 2
# Robot_yaw:  266.710395644
# Buoy yaw:  246.432035277
# 3
# Robot_yaw:  266.710395644
# Buoy yaw:  266.710395644
# 4
# list index out of range
# Robot_yaw:  266.673787372
# Buoy yaw:  262.173787372
# 0
# Robot_yaw:  266.673787372
# Buoy yaw:  248.539496676
# 1
# Robot_yaw:  266.673787372
# Buoy yaw:  298.573575274
# 2
# Robot_yaw:  266.673787372
# Buoy yaw:  246.124627368
# 3
# Robot_yaw:  266.673787372
# Buoy yaw:  266.673787372
# 4
# list index out of range
# Robot_yaw:  266.724942984
# Buoy yaw:  262.224942984
# 0
# Robot_yaw:  266.724942984
# Buoy yaw:  248.57435018
# 1
# Robot_yaw:  266.724942984
# Buoy yaw:  298.158124747
# 2
# Robot_yaw:  266.724942984
# Buoy yaw:  246.508470358
# 3
# Robot_yaw:  266.724942984
# Buoy yaw:  236.443692984
# 4
# Robot_yaw:  266.724942984
# Buoy yaw:  266.724942984
# 5
# list index out of range
# Robot_yaw:  266.751216547
# Buoy yaw:  262.282466547
# 0
# Robot_yaw:  266.751216547
# Buoy yaw:  248.719966547
# 1
# Robot_yaw:  266.751216547
# Buoy yaw:  298.497462885
# 2
# Robot_yaw:  266.751216547
# Buoy yaw:  246.532466547
# 3
# Robot_yaw:  266.751216547
# Buoy yaw:  243.771033899
# 4
# Robot_yaw:  266.751216547
# Buoy yaw:  266.751216547
# 5
# list index out of range
# Robot_yaw:  266.769712714
# Buoy yaw:  262.300962714
# 0
# Robot_yaw:  266.769712714
# Buoy yaw:  248.800962714
# 1
# Robot_yaw:  266.769712714
# Buoy yaw:  298.00137165
# 2
# Robot_yaw:  266.769712714
# Buoy yaw:  246.322304038
# 3
# Robot_yaw:  266.769712714
# Buoy yaw:  266.769712714
# 4
# list index out of range
# Robot_yaw:  266.702560357
# Buoy yaw:  262.233810357
# 0
# Robot_yaw:  266.702560357
# Buoy yaw:  248.459436348
# 1
# Robot_yaw:  266.702560357
# Buoy yaw:  298.093162468
# 2
# Robot_yaw:  266.702560357
# Buoy yaw:  246.339601448
# 3
# Robot_yaw:  266.702560357
# Buoy yaw:  266.702560357
# 4
# list index out of range
# Robot_yaw:  266.714599607
# Buoy yaw:  262.245849607
# 0
# Robot_yaw:  266.714599607
# Buoy yaw:  248.683349607
# 1
# Robot_yaw:  266.714599607
# Buoy yaw:  298.111816403
# 2
# Robot_yaw:  266.714599607
# Buoy yaw:  246.212039945
# 3
# Robot_yaw:  266.714599607
# Buoy yaw:  266.714599607
# 4
# list index out of range
# Robot_yaw:  266.666091308
# Buoy yaw:  262.166091308
# 0
# Robot_yaw:  266.666091308
# Buoy yaw:  248.478591308
# 1
# Robot_yaw:  266.666091308
# Buoy yaw:  298.41292511
# 2
# Robot_yaw:  266.666091308
# Buoy yaw:  246.261782989
# 3
# Robot_yaw:  266.666091308
# Buoy yaw:  266.666091308
# 4
# list index out of range
# Robot_yaw:  266.704245468
# Buoy yaw:  262.235495468
# 0
# Robot_yaw:  266.704245468
# Buoy yaw:  248.579245468
# 1
# Robot_yaw:  266.704245468
# Buoy yaw:  298.513617417
# 2
# Robot_yaw:  266.704245468
# Buoy yaw:  246.213053604
# 3
# Robot_yaw:  266.704245468
# Buoy yaw:  266.704245468
# 4
# list index out of range
# Robot_yaw:  266.780002317
# Buoy yaw:  262.311252317
# 0
# Robot_yaw:  266.780002317
# Buoy yaw:  248.686252317
# 1
# Robot_yaw:  266.780002317
# Buoy yaw:  298.332523069
# 2
# Robot_yaw:  266.780002317
# Buoy yaw:  246.498752317
# 3
# Robot_yaw:  266.780002317
# Buoy yaw:  266.780002317
# 4
# list index out of range
# Robot_yaw:  266.669332861
# Buoy yaw:  262.169332861
# 0
# Robot_yaw:  266.669332861
# Buoy yaw:  248.471907019
# 1
# Robot_yaw:  266.669332861
# Buoy yaw:  298.528845191
# 2
# Robot_yaw:  266.669332861
# Buoy yaw:  245.984592795
# 3
# Robot_yaw:  266.669332861
# Buoy yaw:  266.669332861
# 4
# list index out of range
# Robot_yaw:  266.768612713
# Buoy yaw:  248.737362713
# 1
# Robot_yaw:  266.768612713
# Buoy yaw:  298.441380353
# 2
# Robot_yaw:  266.768612713
# Buoy yaw:  246.491074414
# 3
# Robot_yaw:  266.768612713
# Buoy yaw:  266.768612713
# 4
# list index out of range
# Robot_yaw:  266.691957905
# Buoy yaw:  262.254457905
# 0
# Robot_yaw:  266.691957905
# Buoy yaw:  248.566957905
# 1
# Robot_yaw:  266.691957905
# Buoy yaw:  298.629457905
# 2
# Robot_yaw:  266.691957905
# Buoy yaw:  246.286579563
# 3
# Robot_yaw:  266.691957905
# Buoy yaw:  266.691957905
# 4
# list index out of range
# Robot_yaw:  266.745235471
# Buoy yaw:  262.307735471
# 0
# Robot_yaw:  266.745235471
# Buoy yaw:  248.65550807
# 1
# Robot_yaw:  266.745235471
# Buoy yaw:  298.475116758
# 2
# Robot_yaw:  266.745235471
# Buoy yaw:  245.429306058
# 3
# Robot_yaw:  266.745235471
# Buoy yaw:  266.745235471
# 4
# list index out of range
# Robot_yaw:  266.754805389
# Buoy yaw:  262.317305389
# 0
# Robot_yaw:  266.754805389
# Buoy yaw:  248.692305389
# 1
# Robot_yaw:  266.754805389
# Buoy yaw:  298.664030853
# 2
# Robot_yaw:  266.754805389
# Buoy yaw:  246.333901229
# 3
# Robot_yaw:  266.754805389
# Buoy yaw:  266.754805389
# 4
# list index out of range
# Robot_yaw:  266.703743226
# Buoy yaw:  262.266243226
# 0
# Robot_yaw:  266.703743226
# Buoy yaw:  248.609993226
# 1
# Robot_yaw:  266.703743226
# Buoy yaw:  298.766777284
# 2
# Robot_yaw:  266.703743226
# Buoy yaw:  246.299707658
# 3
# Robot_yaw:  266.703743226
# Buoy yaw:  266.703743226
# 4
# list index out of range
# Robot_yaw:  266.764438402
# Buoy yaw:  262.358188402
# 0
# Robot_yaw:  266.764438402
# Buoy yaw:  248.670688402
# 1
# Robot_yaw:  266.764438402
# Buoy yaw:  299.273990404
# 2
# Robot_yaw:  266.764438402
# Buoy yaw:  246.392959368
# 3
# Robot_yaw:  266.764438402
# Buoy yaw:  226.951938447
# 4
# Robot_yaw:  266.764438402
# Buoy yaw:  266.764438402
# 5
# list index out of range
# Robot_yaw:  266.785228318
# Buoy yaw:  262.347728318
# 0
# Robot_yaw:  266.785228318
# Buoy yaw:  248.691478318
# 1
# Robot_yaw:  266.785228318
# Buoy yaw:  298.81078679
# 2
# Robot_yaw:  266.785228318
# Buoy yaw:  246.413137025
# 3
# Robot_yaw:  266.785228318
# Buoy yaw:  266.785228318
# 4
# list index out of range
# Robot_yaw:  266.707515353
# Buoy yaw:  262.270015353
# 0
# Robot_yaw:  266.707515353
# Buoy yaw:  248.551265353
# 1
# Robot_yaw:  266.707515353
# Buoy yaw:  299.292262668
# 2
# Robot_yaw:  266.707515353
# Buoy yaw:  246.270013446
# 3
# Robot_yaw:  266.707515353
# Buoy yaw:  266.707515353
# 4
# list index out of range
# Robot_yaw:  266.717515198
# Buoy yaw:  262.322701661
# 0
# Robot_yaw:  266.717515198
# Buoy yaw:  248.570964066
# 1
# Robot_yaw:  266.717515198
# Buoy yaw:  298.973481385
# 2
# Robot_yaw:  266.717515198
# Buoy yaw:  246.110701767
# 3
# Robot_yaw:  266.717515198
# Buoy yaw:  266.717515198
# 4
# list index out of range
# Robot_yaw:  266.716709645
# Buoy yaw:  262.279209645
# 0
# Robot_yaw:  266.716709645
# Buoy yaw:  248.591709645
# 1
# Robot_yaw:  266.716709645
# Buoy yaw:  299.030628713
# 2
# Robot_yaw:  266.716709645
# Buoy yaw:  246.313734563
# 3
# Robot_yaw:  266.716709645
# Buoy yaw:  266.716709645
# 4
# list index out of range
# Robot_yaw:  266.690818382
# Buoy yaw:  262.253318382
# 0
# Robot_yaw:  266.690818382
# Buoy yaw:  248.534568382
# 1
# Robot_yaw:  266.690818382
# Buoy yaw:  299.414924217
# 2
# Robot_yaw:  266.690818382
# Buoy yaw:  245.935966088
# 3
# Robot_yaw:  266.690818382
# Buoy yaw:  266.690818382
# 4
# list index out of range
# Robot_yaw:  266.751477552
# Buoy yaw:  262.345227552
# 0
# Robot_yaw:  266.751477552
# Buoy yaw:  248.688977552
# 1
# Robot_yaw:  266.751477552
# Buoy yaw:  299.418027235
# 2
# Robot_yaw:  266.751477552
# Buoy yaw:  246.336821867
# 3
# Robot_yaw:  266.751477552
# Buoy yaw:  266.751477552
# 4
# list index out of range
# Robot_yaw:  266.702024346
# Buoy yaw:  262.295774346
# 0
# Robot_yaw:  266.702024346
# Buoy yaw:  248.577024346
# 1
# Robot_yaw:  266.702024346
# Buoy yaw:  299.04761303
# 2
# Robot_yaw:  266.702024346
# Buoy yaw:  245.949268227
# 3
# Robot_yaw:  266.702024346
# Buoy yaw:  266.702024346
# 4
# list index out of range
# Robot_yaw:  266.658743931
# Buoy yaw:  262.252493931
# 0
# Robot_yaw:  266.658743931
# Buoy yaw:  248.53236301
# 1
# Robot_yaw:  266.658743931
# Buoy yaw:  246.162163807
# 2
# Robot_yaw:  266.658743931
# Buoy yaw:  266.658743931
# 3
# list index out of range
# Robot_yaw:  266.660001927
# Buoy yaw:  262.253751927
# 0
# Robot_yaw:  266.660001927
# Buoy yaw:  248.503751927
# 1
# Robot_yaw:  266.660001927
# Buoy yaw:  299.076437169
# 2
# Robot_yaw:  266.660001927
# Buoy yaw:  246.163477116
# 3
# Robot_yaw:  266.660001927
# Buoy yaw:  266.660001927
# 4
# list index out of range
# Robot_yaw:  266.701160602
# Buoy yaw:  262.294910602
# 0
# Robot_yaw:  266.701160602
# Buoy yaw:  248.607410602
# 1
# Robot_yaw:  266.701160602
# Buoy yaw:  299.281643085
# 2
# Robot_yaw:  266.701160602
# Buoy yaw:  246.419910602
# 3
# Robot_yaw:  266.701160602
# Buoy yaw:  266.701160602
# 4
# list index out of range
# Robot_yaw:  266.761363037
# Buoy yaw:  262.355113037
# 0
# Robot_yaw:  266.761363037
# Buoy yaw:  248.667613037
# 1
# Robot_yaw:  266.761363037
# Buoy yaw:  299.255412109
# 2
# Robot_yaw:  266.761363037
# Buoy yaw:  246.357951172
# 3
# Robot_yaw:  266.761363037
# Buoy yaw:  266.761363037
# 4
# list index out of range
# Robot_yaw:  266.777361426
# Buoy yaw:  262.371111426
# 0
# Robot_yaw:  266.777361426
# Buoy yaw:  248.683611426
# 1
# Robot_yaw:  266.777361426
# Buoy yaw:  299.536882911
# 2
# Robot_yaw:  266.777361426
# Buoy yaw:  246.373890433
# 3
# Robot_yaw:  266.777361426
# Buoy yaw:  266.777361426
# 4
# list index out of range
# Robot_yaw:  266.764487398
# Buoy yaw:  262.358237398
# 0
# Robot_yaw:  266.764487398
# Buoy yaw:  248.733237398
# 1
# Robot_yaw:  266.764487398
# Buoy yaw:  299.740187776
# 2
# Robot_yaw:  266.764487398
# Buoy yaw:  247.076987398
# 3
# Robot_yaw:  266.764487398
# Buoy yaw:  266.764487398
# 4
# list index out of range
# Robot_yaw:  266.721431356
# Buoy yaw:  262.315181356
# 0
# Robot_yaw:  266.721431356
# Buoy yaw:  248.565181356
# 1
# Robot_yaw:  266.721431356
# Buoy yaw:  299.31286202
# 2
# Robot_yaw:  266.721431356
# Buoy yaw:  246.25553475
# 3
# Robot_yaw:  266.721431356
# Buoy yaw:  266.721431356
# 4
# list index out of range
# Robot_yaw:  266.671875856
# Buoy yaw:  262.234375856
# 0
# Robot_yaw:  266.671875856
# Buoy yaw:  248.453125856
# 1
# Robot_yaw:  266.671875856
# Buoy yaw:  299.6238183
# 2
# Robot_yaw:  266.671875856
# Buoy yaw:  246.1128911
# 3
# Robot_yaw:  266.671875856
# Buoy yaw:  266.671875856
# 4
# list index out of range
# Robot_yaw:  266.741374248
# Buoy yaw:  262.366374248
# 0
# Robot_yaw:  266.741374248
# Buoy yaw:  248.678874248
# 1
# Robot_yaw:  266.741374248
# Buoy yaw:  299.353396648
# 2
# Robot_yaw:  266.741374248
# Buoy yaw:  246.335124248
# 3
# Robot_yaw:  266.741374248
# Buoy yaw:  266.741374248
# 4
# list index out of range
# Robot_yaw:  266.647029274
# Buoy yaw:  262.240779274
# 0
# Robot_yaw:  266.647029274
# Buoy yaw:  248.490779274
# 1
# Robot_yaw:  266.647029274
# Buoy yaw:  299.272029274
# 2
# Robot_yaw:  266.647029274
# Buoy yaw:  246.118255012
# 3
# Robot_yaw:  266.647029274
# Buoy yaw:  266.647029274
# 4
# list index out of range
# Robot_yaw:  266.754006918
# Buoy yaw:  262.347756918
# 0
# Robot_yaw:  266.754006918
# Buoy yaw:  248.660256918
# 1
# Robot_yaw:  266.754006918
# Buoy yaw:  299.513734396
# 2
# Robot_yaw:  266.754006918
# Buoy yaw:  245.740029868
# 3
# Robot_yaw:  266.754006918
# Buoy yaw:  266.754006918
# 4
# list index out of range
# Robot_yaw:  266.683811379
# Buoy yaw:  262.308811379
# 0
# Robot_yaw:  266.683811379
# Buoy yaw:  248.590061379
# 1
# Robot_yaw:  266.683811379
# Buoy yaw:  299.604252053
# 2
# Robot_yaw:  266.683811379
# Buoy yaw:  245.831678582
# 3
# Robot_yaw:  266.683811379
# Buoy yaw:  266.683811379
# 4
# list index out of range
# Robot_yaw:  266.767441143
# Buoy yaw:  262.294338573
# 0
# Robot_yaw:  266.767441143
# Buoy yaw:  248.736191143
# 1
# Robot_yaw:  266.767441143
# Buoy yaw:  299.505676616
# 2
# Robot_yaw:  266.767441143
# Buoy yaw:  246.332329143
# 3
# Robot_yaw:  266.767441143
# Buoy yaw:  266.767441143
# 4
# list index out of range
# Robot_yaw:  266.763896967
# Buoy yaw:  262.357646967
# 0
# Robot_yaw:  266.763896967
# Buoy yaw:  248.670146967
# 1
# Robot_yaw:  266.763896967
# Buoy yaw:  299.641742731
# 2
# Robot_yaw:  266.763896967
# Buoy yaw:  246.265924479
# 3
# Robot_yaw:  266.763896967
# Buoy yaw:  266.763896967
# 4
# list index out of range
# Robot_yaw:  266.713660901
# Buoy yaw:  262.307410901
# 0
# Robot_yaw:  266.713660901
# Buoy yaw:  248.494910901
# 1
# Robot_yaw:  266.713660901
# Buoy yaw:  299.958869642
# 2
# Robot_yaw:  266.713660901
# Buoy yaw:  246.153941816
# 3
# Robot_yaw:  266.713660901
# Buoy yaw:  266.713660901
# 4
# list index out of range
# Robot_yaw:  266.663719251
# Buoy yaw:  262.257469251
# 0
# Robot_yaw:  266.663719251
# Buoy yaw:  248.413719251
# 1
# Robot_yaw:  266.663719251
# Buoy yaw:  299.778930738
# 2
# Robot_yaw:  266.663719251
# Buoy yaw:  246.011627271
# 3
# Robot_yaw:  266.663719251
# Buoy yaw:  266.663719251
# 4
# list index out of range
# Robot_yaw:  266.750328861
# Buoy yaw:  262.375328861
# 0
# list index out of range
# Robot_yaw:  266.64585135
# Buoy yaw:  262.27085135
# 0
# Robot_yaw:  266.64585135
# Buoy yaw:  248.45835135
# 1
# Robot_yaw:  266.64585135
# Buoy yaw:  299.705505586
# 2
# Robot_yaw:  266.64585135
# Buoy yaw:  246.054912782
# 3
# Robot_yaw:  266.64585135
# Buoy yaw:  266.64585135
# 4
# list index out of range
# Robot_yaw:  266.69821181
# Buoy yaw:  262.32321181
# 0
# Robot_yaw:  266.69821181
# Buoy yaw:  248.54196181
# 1
# Robot_yaw:  266.69821181
# Buoy yaw:  299.712188861
# 2
# Robot_yaw:  266.69821181
# Buoy yaw:  246.107170245
# 3
# Robot_yaw:  266.69821181
# Buoy yaw:  266.69821181
# 4
# list index out of range
# Robot_yaw:  266.661420104
# Buoy yaw:  262.286420104
# 0
# list index out of range
# Robot_yaw:  266.720623608
# Buoy yaw:  262.345623608
# 0
# Robot_yaw:  266.720623608
# Buoy yaw:  248.658123608
# 1
# Robot_yaw:  266.720623608
# Buoy yaw:  299.832401868
# 2
# Robot_yaw:  266.720623608
# Buoy yaw:  245.270804044
# 3
# Robot_yaw:  266.720623608
# Buoy yaw:  266.720623608
# 4
# list index out of range
# Robot_yaw:  266.752893579
# Buoy yaw:  262.252893579
# 0
# Robot_yaw:  266.752893579
# Buoy yaw:  248.659143579
# 1
# Robot_yaw:  266.752893579
# Buoy yaw:  299.895189417
# 2
# Robot_yaw:  266.752893579
# Buoy yaw:  246.256782663
# 3
# Robot_yaw:  266.752893579
# Buoy yaw:  266.752893579
# 4
# list index out of range
# Robot_yaw:  266.653749609
# Buoy yaw:  262.170961523
# 0
# Robot_yaw:  266.653749609
# Buoy yaw:  248.434999609
# 1
# Robot_yaw:  266.653749609
# Buoy yaw:  300.745287084
# 2
# Robot_yaw:  266.653749609
# Buoy yaw:  245.913660192
# 3
# Robot_yaw:  266.653749609
# Buoy yaw:  266.653749609
# 4
# list index out of range
# Robot_yaw:  266.691626311
# Buoy yaw:  262.660376311
# 0
# Robot_yaw:  266.691626311
# Buoy yaw:  248.566626311
# 1
# Robot_yaw:  266.691626311
# Buoy yaw:  300.043066741
# 2
# Robot_yaw:  266.691626311
# Buoy yaw:  245.989067794
# 3
# Robot_yaw:  266.691626311
# Buoy yaw:  266.691626311
# 4
# list index out of range
# Robot_yaw:  259.382842061
# Buoy yaw:  255.664092061
# 0
# Robot_yaw:  259.382842061
# Buoy yaw:  241.945342061
# 1
# Robot_yaw:  259.382842061
# Buoy yaw:  293.576849935
# 2
# Robot_yaw:  259.382842061
# Buoy yaw:  239.539511678
# 3
# Robot_yaw:  259.382842061
# Buoy yaw:  259.382842061
# 4
# list index out of range
# Robot_yaw:  251.863443668
# Buoy yaw:  259.582193668
# 0
# Robot_yaw:  251.863443668
# Buoy yaw:  246.772566135
# 1
# Robot_yaw:  251.863443668
# Buoy yaw:  246.561525638
# 2
# Robot_yaw:  251.863443668
# Buoy yaw:  251.863443668
# 3
# list index out of range
# Robot_yaw:  251.586004708
# Buoy yaw:  259.867254708
# 0
# Robot_yaw:  251.586004708
# Buoy yaw:  246.992254708
# 1
# Robot_yaw:  251.586004708
# Buoy yaw:  246.848024819
# 2
# Robot_yaw:  251.586004708
# Buoy yaw:  251.586004708
# 3
# list index out of range
# Robot_yaw:  251.192713478
# Buoy yaw:  260.317713478
# 0
# Robot_yaw:  251.192713478
# Buoy yaw:  247.692713478
# 1
# Robot_yaw:  251.192713478
# Buoy yaw:  248.661463478
# 2
# Robot_yaw:  251.192713478
# Buoy yaw:  251.192713478
# 3
# list index out of range
# Robot_yaw:  251.047678999
# Buoy yaw:  260.408576063
# 0
# Robot_yaw:  251.047678999
# Buoy yaw:  247.860178999
# 1
# Robot_yaw:  251.047678999
# Buoy yaw:  248.703928999
# 2
# Robot_yaw:  251.047678999
# Buoy yaw:  251.047678999
# 3
# list index out of range
# Robot_yaw:  250.92403663
# Buoy yaw:  260.51778663
# 0
# Robot_yaw:  250.92403663
# Buoy yaw:  247.64278663
# 1
# Robot_yaw:  250.92403663
# Buoy yaw:  248.83028663
# 2
# Robot_yaw:  250.92403663
# Buoy yaw:  250.92403663
# 3
# list index out of range
# Robot_yaw:  250.997098509
# Buoy yaw:  260.684598509
# 0
# Robot_yaw:  250.997098509
# Buoy yaw:  247.997098509
# 1
# Robot_yaw:  250.997098509
# Buoy yaw:  249.340848509
# 2
# Robot_yaw:  250.997098509
# Buoy yaw:  250.997098509
# 3
# list index out of range
# Robot_yaw:  250.968385196
# Buoy yaw:  260.655885196
# 0
# Robot_yaw:  250.968385196
# Buoy yaw:  247.999635196
# 1
# Robot_yaw:  250.968385196
# Buoy yaw:  249.45951984
# 2
# Robot_yaw:  250.968385196
# Buoy yaw:  250.968385196
# 3
# list index out of range
# Robot_yaw:  250.957965797
# Buoy yaw:  260.614215797
# 0
# Robot_yaw:  250.957965797
# Buoy yaw:  247.989215797
# 1
# Robot_yaw:  250.957965797
# Buoy yaw:  249.771747535
# 2
# Robot_yaw:  250.957965797
# Buoy yaw:  250.957965797
# 3
# list index out of range
# Robot_yaw:  250.956748988
# Buoy yaw:  260.612998988
# 0
# Robot_yaw:  250.956748988
# Buoy yaw:  247.987998988
# 1
# Robot_yaw:  250.956748988
# Buoy yaw:  249.456748988
# 2
# Robot_yaw:  250.956748988
# Buoy yaw:  250.956748988
# 3
# list index out of range
# Robot_yaw:  250.97340639
# Buoy yaw:  260.69215639
# 0
# Robot_yaw:  250.97340639
# Buoy yaw:  248.00465639
# 1
# Robot_yaw:  250.97340639
# Buoy yaw:  249.180891589
# 2
# Robot_yaw:  250.97340639
# Buoy yaw:  222.08278139
# 3
# Robot_yaw:  250.97340639
# Buoy yaw:  215.429656104
# 4
# Robot_yaw:  250.97340639
# Buoy yaw:  250.97340639
# 5
# list index out of range
# Robot_yaw:  251.008228754
# Buoy yaw:  260.758228754
# 0
# Robot_yaw:  251.008228754
# Buoy yaw:  248.008228754
# 1
# Robot_yaw:  251.008228754
# Buoy yaw:  249.601978754
# 2
# Robot_yaw:  251.008228754
# Buoy yaw:  224.329864954
# 3
# Robot_yaw:  251.008228754
# Buoy yaw:  251.008228754
# 4
# list index out of range
# Robot_yaw:  251.050018751
# Buoy yaw:  260.675018751
# 0
# Robot_yaw:  251.050018751
# Buoy yaw:  248.081268751
# 1
# Robot_yaw:  251.050018751
# Buoy yaw:  249.772777998
# 2
# Robot_yaw:  251.050018751
# Buoy yaw:  227.664242231
# 3
# Robot_yaw:  251.050018751
# Buoy yaw:  251.050018751
# 4
# list index out of range
# Robot_yaw:  251.05032395
# Buoy yaw:  260.64407395
# 0
# list index out of range
# Robot_yaw:  251.029876735
# Buoy yaw:  260.686126735
# 0
# Robot_yaw:  251.029876735
# Buoy yaw:  248.061126735
# 1
# Robot_yaw:  251.029876735
# Buoy yaw:  249.717376735
# 2
# Robot_yaw:  251.029876735
# Buoy yaw:  229.786750819
# 3
# list index out of range
# Robot_yaw:  250.985191805
# Buoy yaw:  260.672691805
# 0
# Robot_yaw:  250.985191805
# Buoy yaw:  248.016441805
# 1
# Robot_yaw:  250.985191805
# Buoy yaw:  249.672691805
# 2
# Robot_yaw:  250.985191805
# Buoy yaw:  250.985191805
# 3
# list index out of range
# Robot_yaw:  250.985741191
# Buoy yaw:  260.578457408
# 0
# Robot_yaw:  250.985741191
# Buoy yaw:  248.016991191
# 1
# Robot_yaw:  250.985741191
# Buoy yaw:  249.673241191
# 2
# Robot_yaw:  250.985741191
# Buoy yaw:  250.985741191
# 3
# list index out of range
# Robot_yaw:  251.102814245
# Buoy yaw:  260.790314245
# 0
# Robot_yaw:  251.102814245
# Buoy yaw:  248.165314245
# 1
# Robot_yaw:  251.102814245
# Buoy yaw:  249.852814245
# 2
# Robot_yaw:  251.102814245
# Buoy yaw:  251.102814245
# 3
# list index out of range
# Robot_yaw:  251.057460567
# Buoy yaw:  249.624053737
# 2
# Robot_yaw:  251.057460567
# Buoy yaw:  251.057460567
# 3
# list index out of range
# Robot_yaw:  251.039030748
# Buoy yaw:  260.726530748
# 0
# Robot_yaw:  251.039030748
# Buoy yaw:  248.070280748
# 1
# Robot_yaw:  251.039030748
# Buoy yaw:  249.851530748
# 2
# Robot_yaw:  251.039030748
# Buoy yaw:  211.289030733
# 3
# Robot_yaw:  251.039030748
# Buoy yaw:  251.039030748
# 4
# list index out of range
# Robot_yaw:  251.054499586
# Buoy yaw:  260.773249586
# 0
# Robot_yaw:  251.054499586
# Buoy yaw:  248.085749586
# 1
# Robot_yaw:  251.054499586
# Buoy yaw:  249.866999586
# 2
# Robot_yaw:  251.054499586
# Buoy yaw:  251.054499586
# 3
# list index out of range
# Robot_yaw:  251.072599036
# Buoy yaw:  260.760099036
# 0
# Robot_yaw:  251.072599036
# Buoy yaw:  248.103849036
# 1
# Robot_yaw:  251.072599036
# Buoy yaw:  249.885099036
# 2
# Robot_yaw:  251.072599036
# Buoy yaw:  251.072599036
# 3
# list index out of range
# Robot_yaw:  251.116595929
# Buoy yaw:  260.875262921
# 0
# Robot_yaw:  251.116595929
# Buoy yaw:  248.147845929
# 1
# Robot_yaw:  251.116595929
# Buoy yaw:  249.786414807
# 2
# Robot_yaw:  251.116595929
# Buoy yaw:  251.116595929
# 3
# list index out of range
# Robot_yaw:  251.042357997
# Buoy yaw:  260.729857997
# 0
# Robot_yaw:  251.042357997
# Buoy yaw:  248.073607997
# 1
# Robot_yaw:  251.042357997
# Buoy yaw:  250.035625056
# 2
# Robot_yaw:  251.042357997
# Buoy yaw:  251.042357997
# 3
# list index out of range
# Robot_yaw:  251.117487505
# Buoy yaw:  260.773737505
# 0
# Robot_yaw:  251.117487505
# Buoy yaw:  248.148737505
# 1
# Robot_yaw:  251.117487505
# Buoy yaw:  250.931837634
# 2
# Robot_yaw:  251.117487505
# Buoy yaw:  251.117487505
# 3
# list index out of range
# Robot_yaw:  251.129569074
# Buoy yaw:  260.785819074
# 0
# Robot_yaw:  251.129569074
# Buoy yaw:  248.160819074
# 1
# Robot_yaw:  251.129569074
# Buoy yaw:  249.973319074
# 2
# Robot_yaw:  251.129569074
# Buoy yaw:  232.379569074
# 3
# Robot_yaw:  251.129569074
# Buoy yaw:  251.129569074
# 4
# list index out of range
# Robot_yaw:  251.050256513
# Buoy yaw:  260.706506513
# 0
# Robot_yaw:  251.050256513
# Buoy yaw:  248.081506513
# 1
# Robot_yaw:  251.050256513
# Buoy yaw:  249.925256513
# 2
# Robot_yaw:  251.050256513
# Buoy yaw:  251.050256513
# 3
# list index out of range
# Robot_yaw:  251.121664153
# Buoy yaw:  260.777914153
# 0
# Robot_yaw:  251.121664153
# Buoy yaw:  248.152914153
# 1
# Robot_yaw:  251.121664153
# Buoy yaw:  249.996664153
# 2
# Robot_yaw:  251.121664153
# Buoy yaw:  251.121664153
# 3
# list index out of range
# Robot_yaw:  251.135490462
# Buoy yaw:  248.135490462
# 1
# Robot_yaw:  251.135490462
# Buoy yaw:  250.010490462
# 2
# Robot_yaw:  251.135490462
# Buoy yaw:  251.135490462
# 3
# list index out of range
# Robot_yaw:  251.09522461
# Buoy yaw:  260.78272461
# 0
# Robot_yaw:  251.09522461
# Buoy yaw:  248.12647461
# 1
# Robot_yaw:  251.09522461
# Buoy yaw:  249.91969513
# 2
# Robot_yaw:  251.09522461
# Buoy yaw:  251.09522461
# 3
# list index out of range
# Robot_yaw:  251.078882216
# Buoy yaw:  260.735132216
# 0
# Robot_yaw:  251.078882216
# Buoy yaw:  248.078882216
# 1
# Robot_yaw:  251.078882216
# Buoy yaw:  249.747262953
# 2
# Robot_yaw:  251.078882216
# Buoy yaw:  251.078882216
# 3
# list index out of range
# Robot_yaw:  251.098840159
# Buoy yaw:  260.817590159
# 0
# Robot_yaw:  251.098840159
# Buoy yaw:  248.098840159
# 1
# Robot_yaw:  251.098840159
# Buoy yaw:  249.942590159
# 2
# Robot_yaw:  251.098840159
# Buoy yaw:  251.098840159
# 3
# list index out of range
# Robot_yaw:  251.047402851
# Buoy yaw:  260.766152851
# 0
# Robot_yaw:  251.047402851
# Buoy yaw:  248.078652851
# 1
# Robot_yaw:  251.047402851
# Buoy yaw:  249.922402851
# 2
# Robot_yaw:  251.047402851
# Buoy yaw:  251.047402851
# 3
# list index out of range
# Robot_yaw:  251.042668238
# Buoy yaw:  260.761418238
# 0
# Robot_yaw:  251.042668238
# Buoy yaw:  248.042668238
# 1
# Robot_yaw:  251.042668238
# Buoy yaw:  249.948918238
# 2
# Robot_yaw:  251.042668238
# Buoy yaw:  251.042668238
# 3
# list index out of range
# Robot_yaw:  251.061234621
# Buoy yaw:  260.779984621
# 0
# Robot_yaw:  251.061234621
# Buoy yaw:  248.092484621
# 1
# Robot_yaw:  251.061234621
# Buoy yaw:  249.936234621
# 2
# Robot_yaw:  251.061234621
# Buoy yaw:  251.061234621
# 3
# list index out of range
# Robot_yaw:  251.136011432
# Buoy yaw:  260.823511432
# 0
# Robot_yaw:  251.136011432
# Buoy yaw:  248.167261432
# 1
# Robot_yaw:  251.136011432
# Buoy yaw:  250.042261432
# 2
# Robot_yaw:  251.136011432
# Buoy yaw:  251.136011432
# 3
# list index out of range
# Robot_yaw:  251.139449257
# Buoy yaw:  260.889449257
# 0
# Robot_yaw:  251.139449257
# Buoy yaw:  248.170699257
# 1
# Robot_yaw:  251.139449257
# Buoy yaw:  250.045699257
# 2
# Robot_yaw:  251.139449257
# Buoy yaw:  251.139449257
# 3
# list index out of range
# Robot_yaw:  251.116786688
# Buoy yaw:  260.866786688
# 0
# Robot_yaw:  251.116786688
# Buoy yaw:  248.148036688
# 1
# Robot_yaw:  251.116786688
# Buoy yaw:  250.023036688
# 2
# Robot_yaw:  251.116786688
# Buoy yaw:  251.116786688
# 3
# list index out of range
# Robot_yaw:  251.089168217
# Buoy yaw:  260.776668217
# 0
# Robot_yaw:  251.089168217
# Buoy yaw:  248.120418217
# 1
# Robot_yaw:  251.089168217
# Buoy yaw:  249.995418217
# 2
# Robot_yaw:  251.089168217
# Buoy yaw:  251.089168217
# 3
# list index out of range
# Robot_yaw:  251.070389816
# Buoy yaw:  260.726639816
# 0
# Robot_yaw:  251.070389816
# Buoy yaw:  248.101639816
# 1
# Robot_yaw:  251.070389816
# Buoy yaw:  249.976639816
# 2
# Robot_yaw:  251.070389816
# Buoy yaw:  251.070389816
# 3
# list index out of range
# Robot_yaw:  251.060394078
# Buoy yaw:  260.716644078
# 0
# Robot_yaw:  251.060394078
# Buoy yaw:  248.091644078
# 1
# Robot_yaw:  251.060394078
# Buoy yaw:  249.966644078
# 2
# Robot_yaw:  251.060394078
# Buoy yaw:  251.060394078
# 3
# list index out of range
# Robot_yaw:  251.078953702
# Buoy yaw:  260.860203702
# 0
# Robot_yaw:  251.078953702
# Buoy yaw:  248.078953702
# 1
# Robot_yaw:  251.078953702
# Buoy yaw:  249.985203702
# 2
# Robot_yaw:  251.078953702
# Buoy yaw:  223.453955609
# 3
# Robot_yaw:  251.078953702
# Buoy yaw:  251.078953702
# 4
# list index out of range
# Robot_yaw:  251.120705931
# Buoy yaw:  260.808205931
# 0
# Robot_yaw:  251.120705931
# Buoy yaw:  248.151955931
# 1
# Robot_yaw:  251.120705931
# Buoy yaw:  250.026955931
# 2
# Robot_yaw:  251.120705931
# Buoy yaw:  251.120705931
# 3
# list index out of range
# Robot_yaw:  251.058185933
# Buoy yaw:  260.776935933
# 0
# Robot_yaw:  251.058185933
# Buoy yaw:  248.089435933
# 1
# Robot_yaw:  251.058185933
# Buoy yaw:  250.015377401
# 2
# Robot_yaw:  251.058185933
# Buoy yaw:  251.058185933
# 3
# list index out of range
# Robot_yaw:  251.07413748
# Buoy yaw:  260.79288748
# 0
# list index out of range
# Robot_yaw:  251.104614193
# Buoy yaw:  260.823364193
# 0
# list index out of range
# Robot_yaw:  251.129514834
# Buoy yaw:  260.848264834
# 0
# Robot_yaw:  251.129514834
# Buoy yaw:  248.160764834
# 1
# Robot_yaw:  251.129514834
# Buoy yaw:  250.035764834
# 2
# Robot_yaw:  251.129514834
# Buoy yaw:  251.129514834
# 3
# list index out of range
# Robot_yaw:  251.072416093
# Buoy yaw:  260.791166093
# 0
# Robot_yaw:  251.072416093
# Buoy yaw:  248.103666093
# 1
# Robot_yaw:  251.072416093
# Buoy yaw:  250.054719713
# 2
# Robot_yaw:  251.072416093
# Buoy yaw:  251.072416093
# 3
# list index out of range
# Robot_yaw:  251.047163737
# Buoy yaw:  260.828413737
# 0
# Robot_yaw:  251.047163737
# Buoy yaw:  248.078413737
# 1
# Robot_yaw:  251.047163737
# Buoy yaw:  249.797163737
# 2
# Robot_yaw:  251.047163737
# Buoy yaw:  251.047163737
# 3
# list index out of range
# Robot_yaw:  251.05691735
# Buoy yaw:  260.77566735
# 0
# Robot_yaw:  251.05691735
# Buoy yaw:  248.08816735
# 1
# Robot_yaw:  251.05691735
# Buoy yaw:  250.204080741
# 2
# Robot_yaw:  251.05691735
# Buoy yaw:  251.05691735
# 3
# list index out of range
# Robot_yaw:  251.123398618
# Buoy yaw:  260.842148618
# 0
# Robot_yaw:  251.123398618
# Buoy yaw:  248.154648618
# 1
# Robot_yaw:  251.123398618
# Buoy yaw:  249.873398618
# 2
# Robot_yaw:  251.123398618
# Buoy yaw:  251.123398618
# 3
# list index out of range
# Robot_yaw:  251.140753324
# Buoy yaw:  260.890753324
# 0
# Robot_yaw:  251.140753324
# Buoy yaw:  248.172003324
# 1
# Robot_yaw:  251.140753324
# Buoy yaw:  250.260630186
# 2
# Robot_yaw:  251.140753324
# Buoy yaw:  251.140753324
# 3
# list index out of range
# Robot_yaw:  251.135748365
# Buoy yaw:  260.948248365
# 0
# Robot_yaw:  251.135748365
# Buoy yaw:  248.135748365
# 1
# Robot_yaw:  251.135748365
# Buoy yaw:  250.282865979
# 2
# Robot_yaw:  251.135748365
# Buoy yaw:  251.135748365
# 3
# list index out of range
# Robot_yaw:  251.093504082
# Buoy yaw:  260.843504082
# 0
# Robot_yaw:  251.093504082
# Buoy yaw:  248.124754082
# 1
# Robot_yaw:  251.093504082
# Buoy yaw:  249.371172081
# 2
# Robot_yaw:  251.093504082
# Buoy yaw:  251.093504082
# 3
# list index out of range
# Robot_yaw:  251.071689197
# Buoy yaw:  260.790439197
# 0
# Robot_yaw:  251.071689197
# Buoy yaw:  248.102939197
# 1
# Robot_yaw:  251.071689197
# Buoy yaw:  249.977939197
# 2
# Robot_yaw:  251.071689197
# Buoy yaw:  251.071689197
# 3
# list index out of range
# Robot_yaw:  251.071819276
# Buoy yaw:  260.790569276
# 0
# Robot_yaw:  251.071819276
# Buoy yaw:  248.103069276
# 1
# Robot_yaw:  251.071819276
# Buoy yaw:  249.978069276
# 2
# Robot_yaw:  251.071819276
# Buoy yaw:  251.071819276
# 3
# list index out of range
# Robot_yaw:  251.086973601
# Buoy yaw:  260.899473601
# 0
# Robot_yaw:  251.086973601
# Buoy yaw:  248.086973601
# 1
# Robot_yaw:  251.086973601
# Buoy yaw:  249.961973601
# 2
# Robot_yaw:  251.086973601
# Buoy yaw:  251.086973601
# 3
# list index out of range
# Robot_yaw:  251.04568078
# Buoy yaw:  260.82693078
# 0
# Robot_yaw:  251.04568078
# Buoy yaw:  248.04568078
# 1
# Robot_yaw:  251.04568078
# Buoy yaw:  249.92068078
# 2
# Robot_yaw:  251.04568078
# Buoy yaw:  251.04568078
# 3
# list index out of range
# Robot_yaw:  251.140087162
# Buoy yaw:  260.921337162
# 0
# Robot_yaw:  251.140087162
# Buoy yaw:  248.171337162
# 1
# Robot_yaw:  251.140087162
# Buoy yaw:  250.015087162
# 2
# Robot_yaw:  251.140087162
# Buoy yaw:  251.140087162
# 3
# list index out of range
# Robot_yaw:  251.082728785
# Buoy yaw:  260.832728785
# 0
# list index out of range
# Robot_yaw:  251.067829574
# Buoy yaw:  260.786579574
# 0
# Robot_yaw:  251.067829574
# Buoy yaw:  248.099079574
# 1
# Robot_yaw:  251.067829574
# Buoy yaw:  249.782356704
# 2
# Robot_yaw:  251.067829574
# Buoy yaw:  251.067829574
# 3
# list index out of range
# Robot_yaw:  251.062678003
# Buoy yaw:  260.843928003
# 0
# Robot_yaw:  251.062678003
# Buoy yaw:  248.062678003
# 1
# Robot_yaw:  251.062678003
# Buoy yaw:  250.281428003
# 2
# Robot_yaw:  251.062678003
# Buoy yaw:  251.062678003
# 3
# list index out of range
# Robot_yaw:  251.1019823
# Buoy yaw:  260.9144823
# 0
# list index out of range
# Robot_yaw:  251.137567767
# Buoy yaw:  260.887567767
# 0
# list index out of range
# Robot_yaw:  251.133410191
# Buoy yaw:  260.852160191
# 0
# Robot_yaw:  251.133410191
# Buoy yaw:  248.164660191
# 1
# list index out of range
# Robot_yaw:  251.125714343
# Buoy yaw:  250.053383868
# 2
# Robot_yaw:  251.125714343
# Buoy yaw:  251.125714343
# 3
# list index out of range
# Robot_yaw:  251.10912699
# Buoy yaw:  250.01537699
# 1
# Robot_yaw:  251.10912699
# Buoy yaw:  251.10912699
# 2
# list index out of range
# Robot_yaw:  251.054738152
# Buoy yaw:  260.929738152
# 0
# Robot_yaw:  251.054738152
# Buoy yaw:  247.992238152
# 1
# Robot_yaw:  251.054738152
# Buoy yaw:  249.960988152
# 2
# Robot_yaw:  251.054738152
# Buoy yaw:  251.054738152
# 3
# list index out of range
# Robot_yaw:  251.127240559
# Buoy yaw:  260.939740559
# 0
# Robot_yaw:  251.127240559
# Buoy yaw:  248.158490559
# 1
# Robot_yaw:  251.127240559
# Buoy yaw:  250.033490559
# 2
# Robot_yaw:  251.127240559
# Buoy yaw:  251.127240559
# 3
# list index out of range
# Robot_yaw:  251.138724988
# Buoy yaw:  260.982474988
# 0
# list index out of range
# Robot_yaw:  251.128599049
# Buoy yaw:  260.998678089
# 0
# Robot_yaw:  251.128599049
# Buoy yaw:  248.222349049
# 1
# Robot_yaw:  251.128599049
# Buoy yaw:  250.034849049
# 2
# Robot_yaw:  251.128599049
# Buoy yaw:  251.128599049
# 3
# list index out of range
# Robot_yaw:  251.110221539
# Buoy yaw:  250.196651135
# 2
# Robot_yaw:  251.110221539
# Buoy yaw:  251.110221539
# 3
# list index out of range
# Robot_yaw:  251.090275527
# Buoy yaw:  260.902775527
# 0
# Robot_yaw:  251.090275527
# Buoy yaw:  248.121525527
# 1
# Robot_yaw:  251.090275527
# Buoy yaw:  249.996525527
# 2
# Robot_yaw:  251.090275527
# Buoy yaw:  251.090275527
# 3
# list index out of range
# Robot_yaw:  251.07509762
# Buoy yaw:  260.85634762
# 0
# list index out of range
# Robot_yaw:  251.070048383
# Buoy yaw:  260.851298383
# 0
# Robot_yaw:  251.070048383
# Buoy yaw:  248.070048383
# 1
# Robot_yaw:  251.070048383
# Buoy yaw:  249.976298383
# 2
# Robot_yaw:  251.070048383
# Buoy yaw:  251.070048383
# 3
# list index out of range
# Robot_yaw:  251.076263666
# Buoy yaw:  260.920013666
# 0
# Robot_yaw:  251.076263666
# Buoy yaw:  248.076263666
# 1
# Robot_yaw:  251.076263666
# Buoy yaw:  249.982513666
# 2
# Robot_yaw:  251.076263666
# Buoy yaw:  251.076263666
# 3
# list index out of range
# Robot_yaw:  251.084995376
# Buoy yaw:  260.959995376
# 0
# Robot_yaw:  251.084995376
# Buoy yaw:  248.084995376
# 1
# Robot_yaw:  251.084995376
# Buoy yaw:  249.991245376
# 2
# Robot_yaw:  251.084995376
# Buoy yaw:  251.084995376
# 3
# list index out of range
# Robot_yaw:  251.127110896
# Buoy yaw:  260.939610896
# 0
# Robot_yaw:  251.127110896
# Buoy yaw:  248.158360896
# 1
# Robot_yaw:  251.127110896
# Buoy yaw:  250.102223811
# 2
# Robot_yaw:  251.127110896
# Buoy yaw:  251.127110896
# 3
# list index out of range
# Robot_yaw:  251.121324861
# Buoy yaw:  260.902574861
# 0
# Robot_yaw:  251.121324861
# Buoy yaw:  248.246324861
# 1
# Robot_yaw:  251.121324861
# Buoy yaw:  249.871324861
# 2
# Robot_yaw:  251.121324861
# Buoy yaw:  251.121324861
# 3
# list index out of range
# Robot_yaw:  251.100501019
# Buoy yaw:  260.881751019
# 0
# Robot_yaw:  251.100501019
# Buoy yaw:  248.225501019
# 1
# Robot_yaw:  251.100501019
# Buoy yaw:  250.006751019
# 2
# Robot_yaw:  251.100501019
# Buoy yaw:  251.100501019
# 3
# list index out of range
# Robot_yaw:  251.043529758
# Buoy yaw:  260.887279758
# 0
# Robot_yaw:  251.043529758
# Buoy yaw:  248.199779758
# 1
# Robot_yaw:  251.043529758
# Buoy yaw:  249.949779758
# 2
# list index out of range
# Robot_yaw:  251.065662867
# Buoy yaw:  260.909412867
# 0
# Robot_yaw:  251.065662867
# Buoy yaw:  248.096912867
# 1
# Robot_yaw:  251.065662867
# Buoy yaw:  249.971912867
# 2
# Robot_yaw:  251.065662867
# Buoy yaw:  251.065662867
# 3
# list index out of range
# Robot_yaw:  251.137419753
# Buoy yaw:  260.981169753
# 0
# Robot_yaw:  251.137419753
# Buoy yaw:  248.168669753
# 1
# Robot_yaw:  251.137419753
# Buoy yaw:  250.043669753
# 2
# Robot_yaw:  251.137419753
# Buoy yaw:  251.137419753
# 3
# list index out of range
# Robot_yaw:  251.056918709
# Buoy yaw:  260.838168709
# 0
# Robot_yaw:  251.056918709
# Buoy yaw:  248.088168709
# 1
# Robot_yaw:  251.056918709
# Buoy yaw:  249.963168709
# 2
# Robot_yaw:  251.056918709
# Buoy yaw:  251.056918709
# 3
# list index out of range
# Robot_yaw:  251.055410977
# Buoy yaw:  260.899160977
# 0
# Robot_yaw:  251.055410977
# Buoy yaw:  248.055410977
# 1
# Robot_yaw:  251.055410977
# Buoy yaw:  249.961660977
# 2
# Robot_yaw:  251.055410977
# Buoy yaw:  251.055410977
# 3
# list index out of range
# Robot_yaw:  251.060966066
# Buoy yaw:  260.904716066
# 0
# Robot_yaw:  251.060966066
# Buoy yaw:  248.060966066
# 1
# Robot_yaw:  251.060966066
# Buoy yaw:  249.491042665
# 2
# Robot_yaw:  251.060966066
# Buoy yaw:  251.060966066
# 3
# list index out of range
# Robot_yaw:  251.094772561
# Buoy yaw:  261.01955436
# 0
# Robot_yaw:  251.094772561
# Buoy yaw:  248.094772561
# 1
# Robot_yaw:  251.094772561
# Buoy yaw:  250.001022561
# 2
# Robot_yaw:  251.094772561
# Buoy yaw:  251.094772561
# 3
# list index out of range
# Robot_yaw:  251.118455106
# Buoy yaw:  260.993455106
# 0
# Robot_yaw:  251.118455106
# Buoy yaw:  248.149705106
# 1
# Robot_yaw:  251.118455106
# Buoy yaw:  249.993455106
# 2
# Robot_yaw:  251.118455106
# Buoy yaw:  224.812206441
# 3
# Robot_yaw:  251.118455106
# Buoy yaw:  251.118455106
# 4
# list index out of range
# Robot_yaw:  251.134704669
# Buoy yaw:  261.058750231
# 0
# Robot_yaw:  251.134704669
# Buoy yaw:  248.165954669
# 1
# Robot_yaw:  251.134704669
# Buoy yaw:  250.040954669
# 2
# Robot_yaw:  251.134704669
# Buoy yaw:  251.134704669
# 3
# list index out of range
# Robot_yaw:  251.05010068
# Buoy yaw:  260.92510068
# 0
# Robot_yaw:  251.05010068
# Buoy yaw:  248.01885068
# 1
# Robot_yaw:  251.05010068
# Buoy yaw:  249.95635068
# 2
# Robot_yaw:  251.05010068
# Buoy yaw:  230.91538846
# 3
# Robot_yaw:  251.05010068
# Buoy yaw:  251.05010068
# 4
# list index out of range
# Robot_yaw:  251.072925679
# Buoy yaw:  260.979175679
# 0
# Robot_yaw:  251.072925679
# Buoy yaw:  248.041675679
# 1
# Robot_yaw:  251.072925679
# Buoy yaw:  250.010425679
# 2
# Robot_yaw:  251.072925679
# Buoy yaw:  251.072925679
# 3
# list index out of range
# Robot_yaw:  251.036362126
# Buoy yaw:  261.028587773
# 0
# Robot_yaw:  251.036362126
# Buoy yaw:  248.036362126
# 1
# Robot_yaw:  251.036362126
# Buoy yaw:  249.942612126
# 2
# Robot_yaw:  251.036362126
# Buoy yaw:  251.036362126
# 3
# list index out of range
# Robot_yaw:  251.127130592
# Buoy yaw:  261.002130592
# 0
# Robot_yaw:  251.127130592
# Buoy yaw:  248.127130592
# 1
# Robot_yaw:  251.127130592
# Buoy yaw:  250.685979927
# 2
# Robot_yaw:  251.127130592
# Buoy yaw:  226.647754753
# 3
# Robot_yaw:  251.127130592
# Buoy yaw:  251.127130592
# 4
# list index out of range
# Robot_yaw:  251.068200823
# Buoy yaw:  260.974450823
# 0
# Robot_yaw:  251.068200823
# Buoy yaw:  248.068200823
# 1
# Robot_yaw:  251.068200823
# Buoy yaw:  249.974450823
# 2
# Robot_yaw:  251.068200823
# Buoy yaw:  251.068200823
# 3
# list index out of range
# Robot_yaw:  251.084010385
# Buoy yaw:  261.021510385
# 0
# Robot_yaw:  251.084010385
# Buoy yaw:  248.052760385
# 1
# Robot_yaw:  251.084010385
# Buoy yaw:  249.990260385
# 2
# Robot_yaw:  251.084010385
# Buoy yaw:  251.084010385
# 3
# list index out of range
# Robot_yaw:  251.095929317
# Buoy yaw:  260.939679317
# 0
# Robot_yaw:  251.095929317
# Buoy yaw:  248.127179317
# 1
# Robot_yaw:  251.095929317
# Buoy yaw:  250.002179317
# 2
# Robot_yaw:  251.095929317
# Buoy yaw:  251.095929317
# 3
# list index out of range
# Robot_yaw:  251.137980324
# Buoy yaw:  261.044230324
# 0
# Robot_yaw:  251.137980324
# Buoy yaw:  248.137980324
# 1
# Robot_yaw:  251.137980324
# Buoy yaw:  250.044230324
# 2
# Robot_yaw:  251.137980324
# Buoy yaw:  251.137980324
# 3
# list index out of range
# Robot_yaw:  251.14439084
# Buoy yaw:  261.05064084
# 0
# Robot_yaw:  251.14439084
# Buoy yaw:  248.11314084
# 1
# Robot_yaw:  251.14439084
# Buoy yaw:  250.05064084
# 2
# Robot_yaw:  251.14439084
# Buoy yaw:  251.14439084
# 3
# list index out of range
# Robot_yaw:  251.133552865
# Buoy yaw:  261.071052865
# 0
# Robot_yaw:  251.133552865
# Buoy yaw:  248.164802865
# 1
# Robot_yaw:  251.133552865
# Buoy yaw:  250.039802865
# 2
# Robot_yaw:  251.133552865
# Buoy yaw:  251.133552865
# 3
# list index out of range
# Robot_yaw:  251.061641361
# Buoy yaw:  261.030391361
# 0
# Robot_yaw:  251.061641361
# Buoy yaw:  248.061641361
# 1
# Robot_yaw:  251.061641361
# Buoy yaw:  249.967891361
# 2
# Robot_yaw:  251.061641361
# Buoy yaw:  251.061641361
# 3
# list index out of range
# Robot_yaw:  251.093285569
# Buoy yaw:  261.030785569
# 0
# Robot_yaw:  251.093285569
# Buoy yaw:  248.124535569
# 1
# Robot_yaw:  251.093285569
# Buoy yaw:  249.999535569
# 2
# Robot_yaw:  251.093285569
# Buoy yaw:  251.093285569
# 3
# list index out of range
# Robot_yaw:  251.134359429
# Buoy yaw:  260.978109429
# 0
# Robot_yaw:  251.134359429
# Buoy yaw:  248.134359429
# 1
# Robot_yaw:  251.134359429
# Buoy yaw:  250.040609429
# 2
# Robot_yaw:  251.134359429
# Buoy yaw:  251.134359429
# 3
# list index out of range
# Robot_yaw:  251.130325975
# Buoy yaw:  261.005325975
# 0
# Robot_yaw:  251.130325975
# Buoy yaw:  248.130325975
# 1
# Robot_yaw:  251.130325975
# Buoy yaw:  250.036575975
# 2
# Robot_yaw:  251.130325975
# Buoy yaw:  251.130325975
# 3
# list index out of range
# Robot_yaw:  251.104476271
# Buoy yaw:  261.010726271
# 0
# Robot_yaw:  251.104476271
# Buoy yaw:  248.104476271
# 1
# Robot_yaw:  251.104476271
# Buoy yaw:  250.010726271
# 2
# Robot_yaw:  251.104476271
# Buoy yaw:  251.104476271
# 3
# list index out of range
# Robot_yaw:  251.049480056
# Buoy yaw:  260.986980056
# 0
# Robot_yaw:  251.049480056
# Buoy yaw:  248.018230056
# 1
# Robot_yaw:  251.049480056
# Buoy yaw:  249.955730056
# 2
# Robot_yaw:  251.049480056
# Buoy yaw:  251.049480056
# 3
# list index out of range
# Robot_yaw:  251.118838477
# Buoy yaw:  250.025088477
# 2
# Robot_yaw:  251.118838477
# Buoy yaw:  251.118838477
# 3
# list index out of range
# Robot_yaw:  251.073597701
# Buoy yaw:  261.013592513
# 0
# Robot_yaw:  251.073597701
# Buoy yaw:  248.073597701
# 1
# Robot_yaw:  251.073597701
# Buoy yaw:  249.979847701
# 2
# Robot_yaw:  251.073597701
# Buoy yaw:  251.073597701
# 3
# list index out of range
# Robot_yaw:  251.059084098
# Buoy yaw:  260.965334098
# 0
# Robot_yaw:  251.059084098
# Buoy yaw:  248.090334098
# 1
# Robot_yaw:  251.059084098
# Buoy yaw:  249.93903939
# 2
# Robot_yaw:  251.059084098
# Buoy yaw:  251.059084098
# 3
# list index out of range
# Robot_yaw:  251.055049086
# Buoy yaw:  260.961299086
# 0
# Robot_yaw:  251.055049086
# Buoy yaw:  248.086299086
# 1
# Robot_yaw:  251.055049086
# Buoy yaw:  249.961299086
# 2
# Robot_yaw:  251.055049086
# Buoy yaw:  226.652925635
# 3
# Robot_yaw:  251.055049086
# Buoy yaw:  251.055049086
# 4
# list index out of range
# Robot_yaw:  251.086741463
# Buoy yaw:  261.055491463
# 0
# Robot_yaw:  251.086741463
# Buoy yaw:  248.055491463
# 1
# Robot_yaw:  251.086741463
# Buoy yaw:  250.156126992
# 2
# Robot_yaw:  251.086741463
# Buoy yaw:  251.086741463
# 3
# list index out of range
# Robot_yaw:  251.111099771
# Buoy yaw:  261.079849771
# 0
# list index out of range
# Robot_yaw:  251.137551196
# Buoy yaw:  261.043801196
# 0
# list index out of range
# Robot_yaw:  251.127787672
# Buoy yaw:  261.034037672
# 0
# Robot_yaw:  251.127787672
# Buoy yaw:  248.159037672
# 1
# Robot_yaw:  251.127787672
# Buoy yaw:  250.065287672
# 2
# Robot_yaw:  251.127787672
# Buoy yaw:  251.127787672
# 3
# list index out of range
# Robot_yaw:  251.033991123
# Buoy yaw:  260.971491123
# 0
# Robot_yaw:  251.033991123
# Buoy yaw:  248.002741123
# 1
# Robot_yaw:  251.033991123
# Buoy yaw:  249.940241123
# 2
# Robot_yaw:  251.033991123
# Buoy yaw:  251.033991123
# 3
# list index out of range
# Robot_yaw:  251.086911002
# Buoy yaw:  261.024411002
# 0
# Robot_yaw:  251.086911002
# Buoy yaw:  248.118161002
# 1
# Robot_yaw:  251.086911002
# Buoy yaw:  250.024411002
# 2
# Robot_yaw:  251.086911002
# Buoy yaw:  251.086911002
# 3
# list index out of range
# Robot_yaw:  251.066485023
# Buoy yaw:  261.066900825
# 0
# Robot_yaw:  251.066485023
# Buoy yaw:  248.097735023
# 1
# Robot_yaw:  251.066485023
# Buoy yaw:  250.003985023
# 2
# Robot_yaw:  251.066485023
# Buoy yaw:  251.066485023
# 3
# list index out of range
# Robot_yaw:  251.065940168
# Buoy yaw:  261.376609113
# 0
# Robot_yaw:  251.065940168
# Buoy yaw:  248.097190168
# 1
# Robot_yaw:  251.065940168
# Buoy yaw:  250.003440168
# 2
# Robot_yaw:  251.065940168
# Buoy yaw:  251.065940168
# 3
# list index out of range
# Robot_yaw:  251.124432604
# Buoy yaw:  261.030682604
# 0
# Robot_yaw:  251.124432604
# Buoy yaw:  248.124432604
# 1
# Robot_yaw:  251.124432604
# Buoy yaw:  248.433304827
# 2
# Robot_yaw:  251.124432604
# Buoy yaw:  251.124432604
# 3
# list index out of range
# Robot_yaw:  251.040283058
# Buoy yaw:  261.009033058
# 0
# Robot_yaw:  251.040283058
# Buoy yaw:  248.009033058
# 1
# Robot_yaw:  251.040283058
# Buoy yaw:  249.946533058
# 2
# Robot_yaw:  251.040283058
# Buoy yaw:  251.040283058
# 3
# list index out of range
# Robot_yaw:  251.081170132
# Buoy yaw:  261.066826871
# 0
# Robot_yaw:  251.081170132
# Buoy yaw:  248.081170132
# 1
# Robot_yaw:  251.081170132
# Buoy yaw:  249.987420132
# 2
# Robot_yaw:  251.081170132
# Buoy yaw:  251.081170132
# 3
# list index out of range
# Robot_yaw:  251.057389882
# Buoy yaw:  261.088639882
# 0
# Robot_yaw:  251.057389882
# Buoy yaw:  248.026139882
# 1
# Robot_yaw:  251.057389882
# Buoy yaw:  249.994889882
# 2
# Robot_yaw:  251.057389882
# Buoy yaw:  251.057389882
# 3
# list index out of range
# Robot_yaw:  251.073357544
# Buoy yaw:  250.010857544
# 2
# Robot_yaw:  251.073357544
# Buoy yaw:  251.073357544
# 3
# list index out of range
# Robot_yaw:  251.092348554
# Buoy yaw:  261.149931409
# 0
# Robot_yaw:  251.092348554
# Buoy yaw:  248.092348554
# 1
# Robot_yaw:  251.092348554
# Buoy yaw:  249.998598554
# 2
# Robot_yaw:  251.092348554
# Buoy yaw:  251.092348554
# 3
# list index out of range
# Robot_yaw:  251.105739348
# Buoy yaw:  261.158553831
# 0
# Robot_yaw:  251.105739348
# Buoy yaw:  248.105739348
# 1
# Robot_yaw:  251.105739348
# Buoy yaw:  250.011989348
# 2
# Robot_yaw:  251.105739348
# Buoy yaw:  251.105739348
# 3
# list index out of range
# Robot_yaw:  251.069552846
# Buoy yaw:  261.038302846
# 0
# Robot_yaw:  251.069552846
# Buoy yaw:  248.038302846
# 1
# Robot_yaw:  251.069552846
# Buoy yaw:  249.975802846
# 2
# Robot_yaw:  251.069552846
# Buoy yaw:  251.069552846
# 3
# list index out of range
# Robot_yaw:  251.046083606
# Buoy yaw:  261.046083606
# 0
# Robot_yaw:  251.046083606
# Buoy yaw:  248.014833606
# 1
# Robot_yaw:  251.046083606
# Buoy yaw:  249.952333606
# 2
# Robot_yaw:  251.046083606
# Buoy yaw:  251.046083606
# 3
# list index out of range
# Robot_yaw:  251.129029066
# Buoy yaw:  261.160279066
# 0
# Robot_yaw:  251.129029066
# Buoy yaw:  248.097779066
# 1
# Robot_yaw:  251.129029066
# Buoy yaw:  250.035279066
# 2
# Robot_yaw:  251.129029066
# Buoy yaw:  251.129029066
# 3
# list index out of range
# Robot_yaw:  251.115924616
# Buoy yaw:  261.171790857
# 0
# Robot_yaw:  251.115924616
# Buoy yaw:  248.084674616
# 1
# Robot_yaw:  251.115924616
# Buoy yaw:  250.022174616
# 2
# Robot_yaw:  251.115924616
# Buoy yaw:  251.115924616
# 3
# list index out of range
# Robot_yaw:  251.068561639
# Buoy yaw:  261.068561639
# 0
# Robot_yaw:  251.068561639
# Buoy yaw:  248.0897828
# 1
# Robot_yaw:  251.068561639
# Buoy yaw:  249.974811639
# 2
# Robot_yaw:  251.068561639
# Buoy yaw:  251.068561639
# 3
# list index out of range
# Robot_yaw:  251.056450601
# Buoy yaw:  248.087700601
# 1
# Robot_yaw:  251.056450601
# Buoy yaw:  249.993950601
# 2
# Robot_yaw:  251.056450601
# Buoy yaw:  251.056450601
# 3
# list index out of range
# Robot_yaw:  251.067924411
# Buoy yaw:  261.099174411
# 0
# Robot_yaw:  251.067924411
# Buoy yaw:  248.036674411
# 1
# Robot_yaw:  251.067924411
# Buoy yaw:  249.974174411
# 2
# Robot_yaw:  251.067924411
# Buoy yaw:  251.067924411
# 3
# list index out of range
# Robot_yaw:  251.083299769
# Buoy yaw:  261.145799769
# 0
# Robot_yaw:  251.083299769
# Buoy yaw:  248.052049769
# 1
# Robot_yaw:  251.083299769
# Buoy yaw:  250.020799769
# 2
# Robot_yaw:  251.083299769
# Buoy yaw:  251.083299769
# 3
# list index out of range
# Robot_yaw:  251.103316781
# Buoy yaw:  261.197066781
# 0
# Robot_yaw:  251.103316781
# Buoy yaw:  248.072066781
# 1
# Robot_yaw:  251.103316781
# Buoy yaw:  250.606208322
# 2
# Robot_yaw:  251.103316781
# Buoy yaw:  251.103316781
# 3
# list index out of range
# Robot_yaw:  251.126358007
# Buoy yaw:  261.125114416
# 0
# Robot_yaw:  251.126358007
# Buoy yaw:  248.095108007
# 1
# Robot_yaw:  251.126358007
# Buoy yaw:  250.032608007
# 2
# Robot_yaw:  251.126358007
# Buoy yaw:  251.126358007
# 3
# list index out of range
# Robot_yaw:  251.136050586
# Buoy yaw:  261.104800586
# 0
# Robot_yaw:  251.136050586
# Buoy yaw:  248.136050586
# 1
# Robot_yaw:  251.136050586
# Buoy yaw:  250.073550586
# 2
# Robot_yaw:  251.136050586
# Buoy yaw:  251.136050586
# 3
# ...
# Buoy yaw:  248.029731095
# 1
# Robot_yaw:  251.060981095
# Buoy yaw:  250.029731095
# 2
# Robot_yaw:  251.060981095
# Buoy yaw:  251.060981095
# 3
# list index out of range
# Robot_yaw:  251.056235698
# Buoy yaw:  261.337485698
# 0
# Robot_yaw:  251.056235698
# Buoy yaw:  248.024985698
# 1
# Robot_yaw:  251.056235698
# Buoy yaw:  250.056235698
# 2
# Robot_yaw:  251.056235698
# Buoy yaw:  251.056235698
# 3
# list index out of range
# Robot_yaw:  251.055820657
# Buoy yaw:  261.368320657
# 0
# Robot_yaw:  251.055820657
# Buoy yaw:  248.024570657
# 1
# Robot_yaw:  251.055820657
# Buoy yaw:  250.024570657
# 2
# Robot_yaw:  251.055820657
# Buoy yaw:  251.055820657
# 3
# list index out of range
# Robot_yaw:  251.060955263
# Buoy yaw:  261.404705263
# 0
# Robot_yaw:  251.060955263
# Buoy yaw:  247.967205263
# 1
# Robot_yaw:  251.060955263
# Buoy yaw:  250.029705263
# 2
# Robot_yaw:  251.060955263
# Buoy yaw:  251.060955263
# 3
# list index out of range
# Robot_yaw:  251.07534782
# Buoy yaw:  250.04409782
# 2
# Robot_yaw:  251.07534782
# Buoy yaw:  251.07534782
# 3
# list index out of range
# Robot_yaw:  251.092117508
# Buoy yaw:  261.467117508
# 0
# Robot_yaw:  251.092117508
# Buoy yaw:  247.998367508
# 1
# Robot_yaw:  251.092117508
# Buoy yaw:  250.060867508
# 2
# Robot_yaw:  251.092117508
# Buoy yaw:  251.092117508
# 3
# list index out of range
# Robot_yaw:  251.111741105
# Buoy yaw:  250.080491105
# 2
# Robot_yaw:  251.111741105
# Buoy yaw:  251.111741105
# 3
# list index out of range
# Robot_yaw:  251.116410437
# Buoy yaw:  250.085160437
# 2
# Robot_yaw:  251.116410437
# Buoy yaw:  222.769902411
# 3
# Robot_yaw:  251.116410437
# Buoy yaw:  251.116410437
# 4
# list index out of range
# Robot_yaw:  251.06515033
# Buoy yaw:  261.565707276
# 0
# Robot_yaw:  251.06515033
# Buoy yaw:  248.00265033
# 1
# Robot_yaw:  251.06515033
# Buoy yaw:  250.03390033
# 2
# Robot_yaw:  251.06515033
# Buoy yaw:  251.06515033
# 3
# list index out of range
# Robot_yaw:  251.105583343
# Buoy yaw:  248.043083343
# 1
# Robot_yaw:  251.105583343
# Buoy yaw:  250.074333343
# 2
# Robot_yaw:  251.105583343
# Buoy yaw:  232.08451477
# 3
# Robot_yaw:  251.105583343
# Buoy yaw:  232.511833343
# 4
# Robot_yaw:  251.105583343
# Buoy yaw:  233.756527099
# 5
# Robot_yaw:  251.105583343
# Buoy yaw:  251.105583343
# 6
# list index out of range
# Robot_yaw:  251.127915257
# Buoy yaw:  261.471665257
# 0
# Robot_yaw:  251.127915257
# Buoy yaw:  248.065415257
# 1
# Robot_yaw:  251.127915257
# Buoy yaw:  250.096665257
# 2
# Robot_yaw:  251.127915257
# Buoy yaw:  233.377915257
# 3
# Robot_yaw:  251.127915257
# Buoy yaw:  251.127915257
# 4
# list index out of range
# Robot_yaw:  251.051820367
# Buoy yaw:  261.458070367
# 0
# Robot_yaw:  251.051820367
# Buoy yaw:  247.989320367
# 1
# Robot_yaw:  251.051820367
# Buoy yaw:  250.051820367
# 2
# Robot_yaw:  251.051820367
# Buoy yaw:  251.051820367
# 3
# list index out of range
# Robot_yaw:  251.090050409
# Buoy yaw:  261.465050409
# 0
# Robot_yaw:  251.090050409
# Buoy yaw:  248.058800409
# 1
# Robot_yaw:  251.090050409
# Buoy yaw:  250.090050409
# 2
# Robot_yaw:  251.090050409
# Buoy yaw:  251.090050409
# 3
# list index out of range
# Robot_yaw:  251.115505895
# Buoy yaw:  248.084255895
# 1
# Robot_yaw:  251.115505895
# Buoy yaw:  250.115505895
# 2
# Robot_yaw:  251.115505895
# Buoy yaw:  251.115505895
# 3
# list index out of range
# Robot_yaw:  251.124488556
# Buoy yaw:  248.093238556
# 1
# Robot_yaw:  251.124488556
# Buoy yaw:  250.093238556
# 2
# Robot_yaw:  251.124488556
# Buoy yaw:  251.124488556
# 3
# list index out of range
# Robot_yaw:  251.08525707
# Buoy yaw:  261.42900707
# 0
# Robot_yaw:  251.08525707
# Buoy yaw:  248.05400707
# 1
# Robot_yaw:  251.08525707
# Buoy yaw:  250.11650707
# 2
# Robot_yaw:  251.08525707
# Buoy yaw:  251.08525707
# 3
# list index out of range
# Robot_yaw:  251.034105483
# Buoy yaw:  261.377855483
# 0
# Robot_yaw:  251.034105483
# Buoy yaw:  247.971605483
# 1
# Robot_yaw:  251.034105483
# Buoy yaw:  250.034105483
# 2
# Robot_yaw:  251.034105483
# Buoy yaw:  251.034105483
# 3
# list index out of range
# Robot_yaw:  251.041582062
# Buoy yaw:  261.385332062
# 0
# Robot_yaw:  251.041582062
# Buoy yaw:  247.979082062
# 1
# Robot_yaw:  251.041582062
# Buoy yaw:  250.041582062
# 2
# Robot_yaw:  251.041582062
# Buoy yaw:  251.041582062
# 3
# list index out of range
# Robot_yaw:  251.070393117
# Buoy yaw:  261.609558614
# 0
# Robot_yaw:  251.070393117
# Buoy yaw:  248.007893117
# 1
# Robot_yaw:  251.070393117
# Buoy yaw:  250.070393117
# 2
# Robot_yaw:  251.070393117
# Buoy yaw:  251.070393117
# 3
# list index out of range
# Robot_yaw:  251.057740114
# Buoy yaw:  261.424176119
# 0
# Robot_yaw:  251.057740114
# Buoy yaw:  247.995240114
# 1
# Robot_yaw:  251.057740114
# Buoy yaw:  250.057740114
# 2
# Robot_yaw:  251.057740114
# Buoy yaw:  251.057740114
# 3
# list index out of range
# Robot_yaw:  251.059139938
# Buoy yaw:  261.465389938
# 0
# Robot_yaw:  251.059139938
# Buoy yaw:  247.965389938
# 1
# Robot_yaw:  251.059139938
# Buoy yaw:  250.059139938
# 2
# Robot_yaw:  251.059139938
# Buoy yaw:  234.165756912
# 3
# Robot_yaw:  251.059139938
# Buoy yaw:  251.059139938
# 4
# list index out of range
# Robot_yaw:  251.100185359
# Buoy yaw:  261.506435359
# 0
# Robot_yaw:  251.100185359
# Buoy yaw:  248.037685359
# 1
# Robot_yaw:  251.100185359
# Buoy yaw:  250.068935359
# 2
# Robot_yaw:  251.100185359
# Buoy yaw:  251.100185359
# 3
# list index out of range
# Robot_yaw:  251.122565697
# Buoy yaw:  261.466315697
# 0
# Robot_yaw:  251.122565697
# Buoy yaw:  248.091315697
# 1
# Robot_yaw:  251.122565697
# Buoy yaw:  250.091315697
# 2
# Robot_yaw:  251.122565697
# Buoy yaw:  251.122565697
# 3
# list index out of range
# Robot_yaw:  251.127554921
# Buoy yaw:  261.440054921
# 0
# Robot_yaw:  251.127554921
# Buoy yaw:  248.096304921
# 1
# Robot_yaw:  251.127554921
# Buoy yaw:  250.127554921
# 2
# Robot_yaw:  251.127554921
# Buoy yaw:  251.127554921
# 3
# list index out of range
# Robot_yaw:  251.108013301
# Buoy yaw:  261.420513301
# 0
# Robot_yaw:  251.108013301
# Buoy yaw:  248.170513301
# 1
# Robot_yaw:  251.108013301
# Buoy yaw:  250.108013301
# 2
# Robot_yaw:  251.108013301
# Buoy yaw:  251.108013301
# 3
# list index out of range
# Robot_yaw:  251.075433369
# Buoy yaw:  261.450433369
# 0
# Robot_yaw:  251.075433369
# Buoy yaw:  248.012933369
# 1
# Robot_yaw:  251.075433369
# Buoy yaw:  250.075433369
# 2
# Robot_yaw:  251.075433369
# Buoy yaw:  251.075433369
# 3
# list index out of range
# Robot_yaw:  251.03699098
# Buoy yaw:  261.44324098
# 0
# Robot_yaw:  251.03699098
# Buoy yaw:  247.97449098
# 1
# Robot_yaw:  251.03699098
# Buoy yaw:  250.03699098
# 2
# Robot_yaw:  251.03699098
# Buoy yaw:  251.03699098
# 3
# list index out of range
# Robot_yaw:  251.020943089
# Buoy yaw:  261.395943089
# 0
# Robot_yaw:  251.020943089
# Buoy yaw:  247.958443089
# 1
# Robot_yaw:  251.020943089
# Buoy yaw:  249.989693089
# 2
# Robot_yaw:  251.020943089
# Buoy yaw:  251.020943089
# 3
# list index out of range
# Robot_yaw:  251.056339313
# Buoy yaw:  250.056339313
# 2
# Robot_yaw:  251.056339313
# Buoy yaw:  251.056339313
# 3
# list index out of range
# Robot_yaw:  251.105260358
# Buoy yaw:  261.511510358
# 0
# Robot_yaw:  251.105260358
# Buoy yaw:  248.042760358
# 1
# Robot_yaw:  251.105260358
# Buoy yaw:  250.074010358
# 2
# Robot_yaw:  251.105260358
# Buoy yaw:  251.105260358
# 3
# list index out of range
# Robot_yaw:  251.068289067
# Buoy yaw:  261.412039067
# 0
# Robot_yaw:  251.068289067
# Buoy yaw:  248.037039067
# 1
# Robot_yaw:  251.068289067
# Buoy yaw:  250.101557042
# 2
# Robot_yaw:  251.068289067
# Buoy yaw:  251.068289067
# 3
# list index out of range
# Robot_yaw:  251.059154966
# Buoy yaw:  261.402904966
# 0
# Robot_yaw:  251.059154966
# Buoy yaw:  247.996654966
# 1
# Robot_yaw:  251.059154966
# Buoy yaw:  250.059154966
# 2
# Robot_yaw:  251.059154966
# Buoy yaw:  251.059154966
# 3
# list index out of range
# Robot_yaw:  251.053720341
# Buoy yaw:  261.428720341
# 0
# Robot_yaw:  251.053720341
# Buoy yaw:  247.991220341
# 1
# Robot_yaw:  251.053720341
# Buoy yaw:  250.053720341
# 2
# Robot_yaw:  251.053720341
# Buoy yaw:  251.053720341
# 3
# list index out of range
# Robot_yaw:  251.021382397
# Buoy yaw:  261.544186657
# 0
# Robot_yaw:  251.021382397
# Buoy yaw:  247.927632397
# 1
# Robot_yaw:  251.021382397
# Buoy yaw:  250.021382397
# 2
# Robot_yaw:  251.021382397
# Buoy yaw:  251.021382397
# 3
# list index out of range
# Robot_yaw:  251.064985832
# Buoy yaw:  261.471235832
# 0
# Robot_yaw:  251.064985832
# Buoy yaw:  248.002485832
# 1
# Robot_yaw:  251.064985832
# Buoy yaw:  250.064985832
# 2
# Robot_yaw:  251.064985832
# Buoy yaw:  251.064985832
# 3
# list index out of range
# Robot_yaw:  251.125222619
# Buoy yaw:  261.531472619
# 0
# Robot_yaw:  251.125222619
# Buoy yaw:  248.062722619
# 1
# Robot_yaw:  251.125222619
# Buoy yaw:  250.125222619
# 2
# Robot_yaw:  251.125222619
# Buoy yaw:  251.125222619
# 3
# list index out of range
# Robot_yaw:  251.123871369
# Buoy yaw:  261.530121369
# 0
# Robot_yaw:  251.123871369
# Buoy yaw:  248.061371369
# 1
# Robot_yaw:  251.123871369
# Buoy yaw:  250.123871369
# 2
# Robot_yaw:  251.123871369
# Buoy yaw:  251.123871369
# 3
# list index out of range
# Robot_yaw:  251.104648317
# Buoy yaw:  261.542148317
# 0
# Robot_yaw:  251.104648317
# Buoy yaw:  248.042148317
# 1
# Robot_yaw:  251.104648317
# Buoy yaw:  250.104648317
# 2
# Robot_yaw:  251.104648317
# Buoy yaw:  251.104648317
# 3
# list index out of range
# Robot_yaw:  251.081991984
# Buoy yaw:  261.519491984
# 0
# Robot_yaw:  251.081991984
# Buoy yaw:  248.019491984
# 1
# Robot_yaw:  251.081991984
# Buoy yaw:  250.20226176
# 2
# Robot_yaw:  251.081991984
# Buoy yaw:  251.081991984
# 3
# list index out of range
# Robot_yaw:  251.061225196
# Buoy yaw:  261.404975196
# 0
# Robot_yaw:  251.061225196
# Buoy yaw:  247.998725196
# 1
# Robot_yaw:  251.061225196
# Buoy yaw:  250.180922767
# 2
# Robot_yaw:  251.061225196
# Buoy yaw:  251.061225196
# 3
# list index out of range
# Robot_yaw:  251.079078481
# Buoy yaw:  248.016578481
# 1
# Robot_yaw:  251.079078481
# Buoy yaw:  250.079078481
# 2
# Robot_yaw:  251.079078481
# Buoy yaw:  251.079078481
# 3
# list index out of range
# Robot_yaw:  251.031884773
# Buoy yaw:  261.426339729
# 0
# Robot_yaw:  251.031884773
# Buoy yaw:  247.938134773
# 1
# Robot_yaw:  251.031884773
# Buoy yaw:  250.031884773
# 2
# Robot_yaw:  251.031884773
# Buoy yaw:  251.031884773
# 3
# list index out of range
# Robot_yaw:  251.111393459
# Buoy yaw:  248.048893459
# 1
# Robot_yaw:  251.111393459
# Buoy yaw:  250.111393459
# 2
# Robot_yaw:  251.111393459
# Buoy yaw:  251.111393459
# 3
# list index out of range
# Robot_yaw:  251.09393809
# Buoy yaw:  250.09393809
# 2
# Robot_yaw:  251.09393809
# Buoy yaw:  251.09393809
# 3
# list index out of range
# Robot_yaw:  251.053086009
# Buoy yaw:  261.487259593
# 0
# Robot_yaw:  251.053086009
# Buoy yaw:  248.053086009
# 1
# Robot_yaw:  251.053086009
# Buoy yaw:  250.053086009
# 2
# Robot_yaw:  251.053086009
# Buoy yaw:  251.053086009
# 3
# list index out of range
# Robot_yaw:  251.041548888
# Buoy yaw:  261.598200957
# 0
# Robot_yaw:  251.041548888
# Buoy yaw:  247.979048888
# 1
# Robot_yaw:  251.041548888
# Buoy yaw:  250.041548888
# 2
# Robot_yaw:  251.041548888
# Buoy yaw:  251.041548888
# 3
# list index out of range
# Robot_yaw:  251.125900143
# Buoy yaw:  261.532150143
# 0
# Robot_yaw:  251.125900143
# Buoy yaw:  248.094650143
# 1
# Robot_yaw:  251.125900143
# Buoy yaw:  250.09847247
# 2
# Robot_yaw:  251.125900143
# Buoy yaw:  251.125900143
# 3
# list index out of range
# Robot_yaw:  251.104027283
# Buoy yaw:  261.541527283
# 0
# Robot_yaw:  251.104027283
# Buoy yaw:  248.072777283
# 1
# Robot_yaw:  251.104027283
# Buoy yaw:  249.214199555
# 2
# Robot_yaw:  251.104027283
# Buoy yaw:  251.104027283
# 3
# list index out of range
# Robot_yaw:  251.064714071
# Buoy yaw:  261.502214071
# 0
# Robot_yaw:  251.064714071
# Buoy yaw:  248.002214071
# 1
# Robot_yaw:  251.064714071
# Buoy yaw:  250.064714071
# 2
# Robot_yaw:  251.064714071
# Buoy yaw:  251.064714071
# 3
# list index out of range
# Robot_yaw:  251.018071053
# Buoy yaw:  261.486821053
# 0
# Robot_yaw:  251.018071053
# Buoy yaw:  247.955571053
# 1
# Robot_yaw:  251.018071053
# Buoy yaw:  249.986821053
# 2
# Robot_yaw:  251.018071053
# Buoy yaw:  251.018071053
# 3
# list index out of range
# Robot_yaw:  251.028184297
# Buoy yaw:  261.496934297
# 0
# Robot_yaw:  251.028184297
# Buoy yaw:  247.965684297
# 1
# Robot_yaw:  251.028184297
# Buoy yaw:  249.908666017
# 2
# Robot_yaw:  251.028184297
# Buoy yaw:  251.028184297
# 3
# list index out of range
# Robot_yaw:  251.062401715
# Buoy yaw:  261.499901715
# 0
# Robot_yaw:  251.062401715
# Buoy yaw:  247.999901715
# 1
# Robot_yaw:  251.062401715
# Buoy yaw:  250.267147961
# 2
# Robot_yaw:  251.062401715
# Buoy yaw:  251.062401715
# 3
# list index out of range
# Robot_yaw:  251.097338025
# Buoy yaw:  261.534838025
# 0
# list index out of range
# Robot_yaw:  251.114444
# Buoy yaw:  261.583194
# 0
# Robot_yaw:  251.114444
# Buoy yaw:  248.051944
# 1
# Robot_yaw:  251.114444
# Buoy yaw:  250.145694
# 2
# Robot_yaw:  251.114444
# Buoy yaw:  251.114444
# 3
# list index out of range
# Robot_yaw:  251.05143212
# Buoy yaw:  261.48893212
# 0
# Robot_yaw:  251.05143212
# Buoy yaw:  247.98893212
# 1
# Robot_yaw:  251.05143212
# Buoy yaw:  250.08268212
# 2
# Robot_yaw:  251.05143212
# Buoy yaw:  251.05143212
# 3
# list index out of range
# Robot_yaw:  251.051525079
# Buoy yaw:  247.989025079
# 1
# Robot_yaw:  251.051525079
# Buoy yaw:  250.082775079
# 2
# Robot_yaw:  251.051525079
# Buoy yaw:  251.051525079
# 3
# list index out of range
# Robot_yaw:  251.057037547
# Buoy yaw:  261.588287547
# 0
# Robot_yaw:  251.057037547
# Buoy yaw:  247.963287547
# 1
# Robot_yaw:  251.057037547
# Buoy yaw:  250.057037547
# 2
# Robot_yaw:  251.057037547
# Buoy yaw:  251.057037547
# 3
# list index out of range
# Robot_yaw:  251.112504923
# Buoy yaw:  248.081254923
# 1
# Robot_yaw:  251.112504923
# Buoy yaw:  250.143754923
# 2
# Robot_yaw:  251.112504923
# Buoy yaw:  251.112504923
# 3
# list index out of range
# Robot_yaw:  251.092328297
# Buoy yaw:  261.529828297
# 0
# Robot_yaw:  251.092328297
# Buoy yaw:  248.029828297
# 1
# Robot_yaw:  251.092328297
# Buoy yaw:  250.123578297
# 2
# Robot_yaw:  251.092328297
# Buoy yaw:  251.092328297
# 3
# list index out of range
# Robot_yaw:  251.056387619
# Buoy yaw:  261.525137619
# 0
# Robot_yaw:  251.056387619
# Buoy yaw:  247.993887619
# 1
# Robot_yaw:  251.056387619
# Buoy yaw:  250.056387619
# 2
# Robot_yaw:  251.056387619
# Buoy yaw:  251.056387619
# 3
# list index out of range
# Robot_yaw:  251.020557096
# Buoy yaw:  261.520557096
# 0
# Robot_yaw:  251.020557096
# Buoy yaw:  247.926807096
# 1
# Robot_yaw:  251.020557096
# Buoy yaw:  250.020557096
# 2
# Robot_yaw:  251.020557096
# Buoy yaw:  251.020557096
# 3
# list index out of range
# Robot_yaw:  251.061290725
# Buoy yaw:  261.556735976
# 0
# Robot_yaw:  251.061290725
# Buoy yaw:  247.967540725
# 1
# Robot_yaw:  251.061290725
# Buoy yaw:  250.012676223
# 2
# Robot_yaw:  251.061290725
# Buoy yaw:  251.061290725
# 3
# list index out of range
# Robot_yaw:  251.04571806
# Buoy yaw:  261.48321806
# 0
# Robot_yaw:  251.04571806
# Buoy yaw:  247.98321806
# 1
# Robot_yaw:  251.04571806
# Buoy yaw:  250.04571806
# 2
# Robot_yaw:  251.04571806
# Buoy yaw:  251.04571806
# 3
# list index out of range
# Robot_yaw:  251.037346181
# Buoy yaw:  261.474846181
# 0
# Robot_yaw:  251.037346181
# Buoy yaw:  247.974846181
# 1
# Robot_yaw:  251.037346181
# Buoy yaw:  250.037346181
# 2
# Robot_yaw:  251.037346181
# Buoy yaw:  251.037346181
# 3
# list index out of range
# Robot_yaw:  251.038095407
# Buoy yaw:  261.538095407
# 0
# list index out of range
# Robot_yaw:  251.048756593
# Buoy yaw:  261.611256593
# 0
# Robot_yaw:  251.048756593
# Buoy yaw:  247.955006593
# 1
# Robot_yaw:  251.048756593
# Buoy yaw:  250.080006593
# 2
# Robot_yaw:  251.048756593
# Buoy yaw:  251.048756593
# 3
# list index out of range
# Robot_yaw:  251.06865577
# Buoy yaw:  261.56865577
# 0
# Robot_yaw:  251.06865577
# Buoy yaw:  247.97490577
# 1
# Robot_yaw:  251.06865577
# Buoy yaw:  250.06865577
# 2
# Robot_yaw:  251.06865577
# Buoy yaw:  251.06865577
# 3
# list index out of range
# Robot_yaw:  251.098550209
# Buoy yaw:  261.567300209
# 0
# Robot_yaw:  251.098550209
# Buoy yaw:  248.036050209
# 1
# Robot_yaw:  251.098550209
# Buoy yaw:  250.098550209
# 2
# Robot_yaw:  251.098550209
# Buoy yaw:  251.098550209
# 3
# list index out of range
# Robot_yaw:  251.114615
# Buoy yaw:  261.645865
# 0
# Robot_yaw:  251.114615
# Buoy yaw:  248.052115
# 1
# Robot_yaw:  251.114615
# Buoy yaw:  250.114615
# 2
# Robot_yaw:  251.114615
# Buoy yaw:  251.114615
# 3
# list index out of range
# Robot_yaw:  251.084515447
# Buoy yaw:  261.649327153
# 0
# list index out of range
# Robot_yaw:  251.044897754
# Buoy yaw:  261.513647754
# 0
# Robot_yaw:  251.044897754
# Buoy yaw:  247.982397754
# 1
# Robot_yaw:  251.044897754
# Buoy yaw:  250.076147754
# 2
# Robot_yaw:  251.044897754
# Buoy yaw:  251.044897754
# 3
# list index out of range
# Robot_yaw:  251.05710788
# Buoy yaw:  261.36960788
# 0
# Robot_yaw:  251.05710788
# Buoy yaw:  247.99460788
# 1
# Robot_yaw:  251.05710788
# Buoy yaw:  250.08835788
# 2
# Robot_yaw:  251.05710788
# Buoy yaw:  251.05710788
# 3
# list index out of range
# Robot_yaw:  251.124335994
# Buoy yaw:  261.593085994
# 0
# Robot_yaw:  251.124335994
# Buoy yaw:  248.061835994
# 1
# Robot_yaw:  251.124335994
# Buoy yaw:  250.155585994
# 2
# Robot_yaw:  251.124335994
# Buoy yaw:  251.124335994
# 3
# list index out of range
