# %%
def round_to_odd(i):
    i = round(i)
    if (i % 2) != 1:
        i = i+1
    return(i)

i = 1
while True:
    b_width = round_to_odd(200/i)
    b_length = i
    print "length = ", b_length, " width = ", b_width
    i = i+1
# Out:
# length =  1  width =  201.0
# length =  2  width =  101.0
# length =  3  width =  67.0
# length =  4  width =  51.0
# length =  5  width =  41.0
# length =  6  width =  33.0
# length =  7  width =  29.0
# length =  8  width =  25.0
# length =  9  width =  23.0
# length =  10  width =  21.0
# length =  11  width =  19.0
# length =  12  width =  17.0
# length =  13  width =  15.0
# length =  14  width =  15.0
# length =  15  width =  13.0
# length =  16  width =  13.0
# length =  17  width =  11.0
# length =  18  width =  11.0
# length =  19  width =  11.0
# length =  20  width =  11.0
# length =  21  width =  9.0
# length =  22  width =  9.0
# length =  23  width =  9.0
# length =  24  width =  9.0
# length =  25  width =  9.0
# length =  26  width =  7.0
# length =  27  width =  7.0
# length =  28  width =  7.0
# length =  29  width =  7.0
# length =  30  width =  7.0
# length =  31  width =  7.0
# length =  32  width =  7.0
# length =  33  width =  7.0
# length =  34  width =  5.0
# ...
